# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# physio_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/Physio/periods/features_segm_1.csv"
# driving_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/Driving/features_tor_10s_30s_rows.csv"
# pvt_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/PVT/data_PVT_no_outliers_mean_sd.csv"

# %%
driving_path = "../Exp4/Preprocessed/Driving/features_tor_10s_30s_rows.csv"
pvt_path = "../Exp4/Preprocessed/PVT/data_PVT_no_outliers_mean_sd.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

driving_data = pd.read_csv(driving_path)
pvt_data = pd.read_csv(pvt_path)

# merge two datasets follow by "subject_id"
# inner is used to make sure both dataset include the subject id only to be input into the data
data = pd.merge(driving_data, pvt_data, on='subject_id', how='inner')

print(data.shape)
# Out:
# (58, 29)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   subject_id             58 non-null     int64
#  1   label_sleep            58 non-null     int64
#  2   label_first_scenario   58 non-null     object
#  3   label_time_exp         58 non-null     int64
#  4   period                 58 non-null     object
#  5   TO_Decision_Rural      58 non-null     int64
#  6   TO_RT_Rural            58 non-null     float64
#  7   TO_MaxSWA_Rural        58 non-null     float64
#  8   TO_ReengageTime_Rural  40 non-null     float64
#  9   TO_MaxBraking_Rural    58 non-null     float64
#  10  TO_Decision_Urban      49 non-null     float64
#  11  TO_RT_Urban            49 non-null     float64
#  12  TO_MaxSWA_Urban        49 non-null     float64
#  13  TO_ReengageTime_Urban  39 non-null     float64
#  14  TO_MaxBraking_Urban    49 non-null     float64
#  15  code                   58 non-null     object
#  16  sleep_condition        58 non-null     int64
#  17  time_experiment        58 non-null     int64
#  18  first_scenario         58 non-null     object
#  19  RT_0_City              56 non-null     float64
#  20  RT_1_City              55 non-null     float64
#  21  RT_2_City              50 non-null     float64
#  22  RT_3_City              48 non-null     float64
#  23  RT_4_City              19 non-null     float64
#  24  RT_0_Country           55 non-null     float64
#  25  RT_1_Country           52 non-null     float64
#  26  RT_2_Country           57 non-null     float64
#  27  RT_3_Country           57 non-null     float64
#  28  RT_4_Country           56 non-null     float64
# dtypes: float64(19), int64(6), object(4)
# memory usage: 13.3+ KB

# %%
data.head()
# Out:
#    subject_id  label_sleep label_first_scenario  label_time_exp   period  \
# 0           1            0          Countryside              16  Country
# 1           2            1                Urban              16  Country
# 2           3            0          Countryside              16  Country
# 3           4            1          Countryside              16  Country
# 4           5            0          Countryside              10  Country
#
#    TO_Decision_Rural  TO_RT_Rural  TO_MaxSWA_Rural  TO_ReengageTime_Rural  \
# 0                  1        2.450              5.0                 12.399
# 1                  4        2.900              2.0                  3.233
# 2                  1        2.233              7.0                 25.767
# 3                  4        1.665             37.0                    NaN
# 4                  1        1.467              6.0                  3.750
#
#    TO_MaxBraking_Rural  ...  RT_0_City  RT_1_City  RT_2_City  RT_3_City  \
# 0                100.0  ...   1.081116   0.822021   1.106934   1.363037
# 1                  0.0  ...   0.954437   2.314331        NaN        NaN
# 2                100.0  ...   1.022156   1.008484   1.222046   1.314209
# 3                100.0  ...   1.710815   1.583008   1.559570   1.510010
# 4                100.0  ...   1.815369   1.424805        NaN        NaN
#
#    RT_4_City RT_0_Country  RT_1_Country  RT_2_Country RT_3_Country  \
# 0        NaN     1.299316      3.667419      2.049561     1.050903
# 1        NaN     0.749969      1.362122      1.615845          NaN
# 2   0.899292     0.726898      1.000244      0.831909     1.666626
# 3        NaN     1.700867           NaN      1.499390     1.400513
# 4        NaN     1.666779      1.383423      1.466309     1.500610
#
#    RT_4_Country
# 0      0.699707
# 1      1.899658
# 2      0.900024
# 3      1.433350
# 4      1.433350
#
# [5 rows x 29 columns]

# %%
label_counts = data["label_sleep"].value_counts()
print(label_counts)
# Out:
# label_sleep
# 1    31
# 0    27
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")
plt.title("Class Distribution: label_sleep")
plt.xlabel("Classes")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\kahch\AppData\Local\Temp\ipykernel_54260\3141730654.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")

# %%
columns_to_drop = ["sleep_condition", "code", "first_scenario"]
data = data.drop(columns=columns_to_drop, axis=1)

# %% [markdown]
# #Data Preprocessing

# %%
columns_to_exclude = data.columns[data.isnull().mean() > 0.5]
data = data.drop(columns=columns_to_exclude)

data.replace([np.inf, -np.inf], np.nan, inplace=True)

numerical_data = data.select_dtypes(include=['number'])

missing_values = numerical_data.isnull().sum()
print("Missing Values:\n", missing_values[missing_values > 0])

data.fillna(numerical_data.mean(), inplace=True)

missing_after = data.isnull().sum()
print("\nMissing Values After Filling:\n", missing_after[missing_after > 0])

if missing_after.sum() == 0:
    print("\nAll missing values have been successfully filled!")
else:
    print("\nThere are still missing values in the dataset.")
# Out:
# Missing Values:
#  TO_ReengageTime_Rural    18
# TO_Decision_Urban         9
# TO_RT_Urban               9
# TO_MaxSWA_Urban           9
# TO_ReengageTime_Urban    19
# TO_MaxBraking_Urban       9
# RT_0_City                 2
# RT_1_City                 3
# RT_2_City                 8
# RT_3_City                10
# RT_0_Country              3
# RT_1_Country              6
# RT_2_Country              1
# RT_3_Country              1
# RT_4_Country              2
# dtype: int64
#
# Missing Values After Filling:
#  Series([], dtype: int64)
#
# All missing values have been successfully filled!

# %%
data["label_first_scenario"] = data["label_first_scenario"].map({"Countryside": 0, "Urban": 1})
data["period"] = data["period"].map({"Country": 0, "Urban": 1})

print("\n'label_first_scenario' Column After Encoding:\n", data["label_first_scenario"].head())
print("\n'period' Column After Encoding:\n", data["period"].head())
# Out:
# 'label_first_scenario' Column After Encoding:
#  0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: label_first_scenario, dtype: int64
#
# 'period' Column After Encoding:
#  0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: period, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data["label_sleep"] = label_encoder.fit_transform(data["label_sleep"])

print("Encoded Labels:\n", data["label_sleep"].unique())
# Out:
# Encoded Labels:
#  [0 1]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, precision_score, recall_score, f1_score

X = data.drop(columns=['subject_id', 'label_sleep']).values
y = data['label_sleep'].values

encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y.reshape(-1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

print(f"Training Set Size: {x_train.shape}")
print(f"Testing Set Size: {x_test.shape}")

scaler = StandardScaler()
x_train_norm = scaler.fit_transform(x_train)
x_test_norm = scaler.transform(x_test)
# Out:
# Training Set Size: (46, 23)
# Testing Set Size: (12, 23)

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y), y=y)
class_weights_dict = dict(enumerate(class_weights))

input_size = x_train_norm.shape[1]
output_size = y_train.shape[1]

x_train_cnn = x_train_norm.reshape(x_train_norm.shape[0], x_train_norm.shape[1], 1)
x_test_cnn = x_test_norm.reshape(x_test_norm.shape[0], x_test_norm.shape[1], 1)

model = models.Sequential([
    layers.Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(input_size, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.3),

    layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.3),

    layers.Flatten(),

    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.4),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.4),
    layers.Dense(output_size, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    x_train_cnn, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(x_test_cnn, y_test),
    class_weight=class_weights_dict,
    callbacks=[early_stopping],
    verbose=1
)

val_loss, val_accuracy = model.evaluate(x_test_cnn, y_test, verbose=0)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

y_pred = model.predict(x_test_cnn)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)
# Out:
# Epoch 1/100
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - accuracy: 0.5788 - loss: 3.5831 - val_accuracy: 0.5000 - val_loss: 3.2251
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4502 - loss: 3.5108 - val_accuracy: 0.5000 - val_loss: 3.2023
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5933 - loss: 3.3963 - val_accuracy: 0.5833 - val_loss: 3.1821
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6350 - loss: 3.1820 - val_accuracy: 0.5833 - val_loss: 3.1608
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6037 - loss: 3.1586 - val_accuracy: 0.6667 - val_loss: 3.1396
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5353 - loss: 3.2444 - val_accuracy: 0.6667 - val_loss: 3.1190
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6784 - loss: 3.2692 - val_accuracy: 0.7500 - val_loss: 3.0992
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6454 - loss: 3.1257 - val_accuracy: 0.5833 - val_loss: 3.0800
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4606 - loss: 3.3413 - val_accuracy: 0.5833 - val_loss: 3.0609
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5643 - loss: 3.1970 - val_accuracy: 0.5833 - val_loss: 3.0423
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6639 - loss: 3.0706 - val_accuracy: 0.5833 - val_loss: 3.0239
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4896 - loss: 3.2323 - val_accuracy: 0.5833 - val_loss: 3.0054
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6535 - loss: 2.9130 - val_accuracy: 0.5000 - val_loss: 2.9875
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6390 - loss: 2.9148 - val_accuracy: 0.5000 - val_loss: 2.9699
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7387 - loss: 2.8759 - val_accuracy: 0.5000 - val_loss: 2.9523
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7636 - loss: 2.8735 - val_accuracy: 0.5000 - val_loss: 2.9347
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6889 - loss: 2.8117 - val_accuracy: 0.5000 - val_loss: 2.9170
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7677 - loss: 2.7661 - val_accuracy: 0.5000 - val_loss: 2.8995
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7138 - loss: 2.8011 - val_accuracy: 0.5000 - val_loss: 2.8816
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7074 - loss: 2.7576 - val_accuracy: 0.5000 - val_loss: 2.8638
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6327 - loss: 2.8194 - val_accuracy: 0.5000 - val_loss: 2.8460
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7219 - loss: 2.7373 - val_accuracy: 0.5000 - val_loss: 2.8289
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7138 - loss: 2.6589 - val_accuracy: 0.5000 - val_loss: 2.8119
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7219 - loss: 2.6054 - val_accuracy: 0.5000 - val_loss: 2.7947
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6721 - loss: 2.7362 - val_accuracy: 0.5000 - val_loss: 2.7774
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7468 - loss: 2.5751 - val_accuracy: 0.5833 - val_loss: 2.7600
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8569 - loss: 2.6026 - val_accuracy: 0.5833 - val_loss: 2.7428
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8216 - loss: 2.5605 - val_accuracy: 0.5833 - val_loss: 2.7255
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8175 - loss: 2.4513 - val_accuracy: 0.5833 - val_loss: 2.7078
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8424 - loss: 2.5348 - val_accuracy: 0.5833 - val_loss: 2.6903
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7966 - loss: 2.4714 - val_accuracy: 0.5833 - val_loss: 2.6728
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7034 - loss: 2.5092 - val_accuracy: 0.5833 - val_loss: 2.6553
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8361 - loss: 2.3465 - val_accuracy: 0.5833 - val_loss: 2.6381
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8465 - loss: 2.3688 - val_accuracy: 0.5833 - val_loss: 2.6212
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8569 - loss: 2.2829 - val_accuracy: 0.5833 - val_loss: 2.6050
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8216 - loss: 2.3283 - val_accuracy: 0.5833 - val_loss: 2.5894
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8569 - loss: 2.2838 - val_accuracy: 0.5833 - val_loss: 2.5735
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8111 - loss: 2.3445 - val_accuracy: 0.5000 - val_loss: 2.5573
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8465 - loss: 2.2671 - val_accuracy: 0.5000 - val_loss: 2.5411
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8714 - loss: 2.2327 - val_accuracy: 0.5000 - val_loss: 2.5246
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8361 - loss: 2.2290 - val_accuracy: 0.5000 - val_loss: 2.5081
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8071 - loss: 2.2093 - val_accuracy: 0.5000 - val_loss: 2.4925
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7966 - loss: 2.3506 - val_accuracy: 0.5000 - val_loss: 2.4776
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8320 - loss: 2.1602 - val_accuracy: 0.5000 - val_loss: 2.4622
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8007 - loss: 2.2129 - val_accuracy: 0.5000 - val_loss: 2.4462
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8714 - loss: 2.1389 - val_accuracy: 0.5000 - val_loss: 2.4301
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9253 - loss: 2.0514 - val_accuracy: 0.5000 - val_loss: 2.4146
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9108 - loss: 2.1713 - val_accuracy: 0.5000 - val_loss: 2.4001
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9067 - loss: 1.9855 - val_accuracy: 0.5000 - val_loss: 2.3858
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8256 - loss: 2.0361 - val_accuracy: 0.5000 - val_loss: 2.3722
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8673 - loss: 2.0515 - val_accuracy: 0.5000 - val_loss: 2.3571
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8505 - loss: 1.9801 - val_accuracy: 0.5000 - val_loss: 2.3412
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8465 - loss: 1.9960 - val_accuracy: 0.5000 - val_loss: 2.3258
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8465 - loss: 1.9349 - val_accuracy: 0.5000 - val_loss: 2.3103
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8963 - loss: 1.8857 - val_accuracy: 0.5000 - val_loss: 2.2949
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9316 - loss: 1.9044 - val_accuracy: 0.5833 - val_loss: 2.2792
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8320 - loss: 1.9404 - val_accuracy: 0.5833 - val_loss: 2.2633
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8818 - loss: 1.8989 - val_accuracy: 0.5833 - val_loss: 2.2483
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9316 - loss: 1.8136 - val_accuracy: 0.6667 - val_loss: 2.2350
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9253 - loss: 1.7976 - val_accuracy: 0.6667 - val_loss: 2.2217
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8859 - loss: 1.7900 - val_accuracy: 0.6667 - val_loss: 2.2094
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9606 - loss: 1.6973 - val_accuracy: 0.6667 - val_loss: 2.1970
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9357 - loss: 1.7672 - val_accuracy: 0.6667 - val_loss: 2.1840
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9502 - loss: 1.6895 - val_accuracy: 0.6667 - val_loss: 2.1709
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9461 - loss: 1.6540 - val_accuracy: 0.6667 - val_loss: 2.1569
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9108 - loss: 1.7111 - val_accuracy: 0.6667 - val_loss: 2.1420
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9067 - loss: 1.7060 - val_accuracy: 0.6667 - val_loss: 2.1276
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9108 - loss: 1.6560 - val_accuracy: 0.6667 - val_loss: 2.1132
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9606 - loss: 1.5939 - val_accuracy: 0.6667 - val_loss: 2.0994
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9606 - loss: 1.6092 - val_accuracy: 0.6667 - val_loss: 2.0860
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9606 - loss: 1.5866 - val_accuracy: 0.6667 - val_loss: 2.0722
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9108 - loss: 1.5650 - val_accuracy: 0.6667 - val_loss: 2.0583
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9855 - loss: 1.5356 - val_accuracy: 0.6667 - val_loss: 2.0443
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9108 - loss: 1.5752 - val_accuracy: 0.6667 - val_loss: 2.0305
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9606 - loss: 1.5282 - val_accuracy: 0.6667 - val_loss: 2.0172
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9751 - loss: 1.5090 - val_accuracy: 0.6667 - val_loss: 2.0039
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9606 - loss: 1.5033 - val_accuracy: 0.6667 - val_loss: 1.9909
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9565 - loss: 1.5529 - val_accuracy: 0.6667 - val_loss: 1.9801
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9606 - loss: 1.4805 - val_accuracy: 0.6667 - val_loss: 1.9705
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9606 - loss: 1.4325 - val_accuracy: 0.6667 - val_loss: 1.9610
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8859 - loss: 1.4493 - val_accuracy: 0.5833 - val_loss: 1.9500
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9751 - loss: 1.3746 - val_accuracy: 0.5833 - val_loss: 1.9398
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9502 - loss: 1.4061 - val_accuracy: 0.5833 - val_loss: 1.9296
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9751 - loss: 1.4151 - val_accuracy: 0.5833 - val_loss: 1.9165
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9855 - loss: 1.3607 - val_accuracy: 0.5833 - val_loss: 1.9020
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9751 - loss: 1.3582 - val_accuracy: 0.5833 - val_loss: 1.8867
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9253 - loss: 1.3866 - val_accuracy: 0.5833 - val_loss: 1.8722
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9461 - loss: 1.3407 - val_accuracy: 0.5833 - val_loss: 1.8559
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9502 - loss: 1.3016 - val_accuracy: 0.5833 - val_loss: 1.8405
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9357 - loss: 1.3440 - val_accuracy: 0.5833 - val_loss: 1.8260
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9108 - loss: 1.3038 - val_accuracy: 0.6667 - val_loss: 1.8134
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9502 - loss: 1.3211 - val_accuracy: 0.6667 - val_loss: 1.8033
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9751 - loss: 1.2399 - val_accuracy: 0.6667 - val_loss: 1.7950
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9606 - loss: 1.2651 - val_accuracy: 0.6667 - val_loss: 1.7859
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9502 - loss: 1.2839 - val_accuracy: 0.6667 - val_loss: 1.7750
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9502 - loss: 1.2395 - val_accuracy: 0.6667 - val_loss: 1.7643
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.1731 - val_accuracy: 0.6667 - val_loss: 1.7535
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9751 - loss: 1.1684 - val_accuracy: 0.6667 - val_loss: 1.7448
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9751 - loss: 1.1631 - val_accuracy: 0.6667 - val_loss: 1.7373
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9751 - loss: 1.1858 - val_accuracy: 0.6667 - val_loss: 1.7284
# Validation Accuracy: 66.67%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step

# %%
print("Classification Report:\n")
print(classification_report(y_true_classes, y_pred_classes))

accuracy = accuracy_score(y_true_classes, y_pred_classes)
if y_test.shape[1] == 2:
    roc_auc = roc_auc_score(y_true_classes, y_pred[:, 1])
else:
    roc_auc = roc_auc_score(y_test, y_pred, multi_class='ovr', average='weighted')

precision = precision_score(y_true_classes, y_pred_classes, average='macro')
recall = recall_score(y_true_classes, y_pred_classes, average='macro')
f1 = f1_score(y_true_classes, y_pred_classes, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         6
#            1       0.60      1.00      0.75         6
#
#     accuracy                           0.67        12
#    macro avg       0.80      0.67      0.62        12
# weighted avg       0.80      0.67      0.62        12
#
# Accuracy: 0.67
# ROC-AUC Score: 0.72
# Precision: 0.80
# Recall: 0.67
# F1-Score: 0.62

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(10, 8))
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc, average_precision_score

plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, 
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves Graph')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred[:, i])
    avg_precision = average_precision_score(y_test[:, i], y_pred[:, i])
    plt.plot(recall, precision, lw=2,
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AP = {avg_precision:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\kahch\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (2.1.0)
# Requirement already satisfied: numpy in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (13.7.1)
# Requirement already satisfied: namex in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kahch\anaconda3\lib\site-packages (from optree->keras->keras-tuner) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kahch\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kahch\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kahch\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)

# %%
import keras_tuner as kt

def build_cnn_model(hp):
    input_size = x_train_cnn.shape[1]
    output_size = y_train.shape[1]

    model = models.Sequential()

    model.add(layers.Conv1D(
        filters=hp.Choice('filters_1', values=[32, 64, 128]),
        kernel_size=hp.Choice('kernel_size_1', values=[3, 5]),
        activation='relu',
        input_shape=(input_size, 1)
    ))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling1D(pool_size=2))
    model.add(layers.Dropout(hp.Choice('dropout_1', values=[0.2, 0.3, 0.4])))

    model.add(layers.Conv1D(
        filters=hp.Choice('filters_2', values=[32, 64]),
        kernel_size=hp.Choice('kernel_size_2', values=[3, 5]),
        activation='relu'
    ))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling1D(pool_size=2))
    model.add(layers.Dropout(hp.Choice('dropout_2', values=[0.2, 0.3, 0.4])))

    model.add(layers.Flatten())

    model.add(layers.Dense(
        units=hp.Choice('units_1', values=[64, 128]),
        activation='relu',
        kernel_regularizer=regularizers.l2(0.01)
    ))
    model.add(layers.Dropout(hp.Choice('dropout_3', values=[0.3, 0.4])))

    model.add(layers.Dense(
        units=hp.Choice('units_2', values=[32, 64]),
        activation='relu',
        kernel_regularizer=regularizers.l2(0.01)
    ))
    model.add(layers.Dropout(hp.Choice('dropout_4', values=[0.3, 0.4])))

    model.add(layers.Dense(output_size, activation='sigmoid'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Choice('learning_rate', values=[0.001, 0.005, 0.01])
        ),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

tuner = kt.Hyperband(
    build_cnn_model,
    objective='val_accuracy',
    max_epochs=50,
    factor=3,
    directory='CNN_Tuning',
    project_name='CNN_Hyperparameter_Tuning'
)

hyper_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

tuner.search(
    x_train_cnn, y_train,
    validation_data=(x_test_cnn, y_test),
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[hyper_early_stopping],
    verbose=1
)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:")
print(f"Filters in Layer 1: {best_hps.get('filters_1')}")
print(f"Kernel Size in Layer 1: {best_hps.get('kernel_size_1')}")
print(f"Dropout in Layer 1: {best_hps.get('dropout_1')}")
print(f"Filters in Layer 2: {best_hps.get('filters_2')}")
print(f"Kernel Size in Layer 2: {best_hps.get('kernel_size_2')}")
print(f"Dropout in Layer 2: {best_hps.get('dropout_2')}")
print(f"Units in Dense Layer 1: {best_hps.get('units_1')}")
print(f"Dropout in Dense Layer 1: {best_hps.get('dropout_3')}")
print(f"Units in Dense Layer 2: {best_hps.get('units_2')}")
print(f"Dropout in Dense Layer 2: {best_hps.get('dropout_4')}")
print(f"Learning Rate: {best_hps.get('learning_rate')}")

best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(
    x_train_cnn, y_train,
    validation_data=(x_test_cnn, y_test),
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[hyper_early_stopping],
    verbose=1
)

y_pred_best = best_model.predict(x_test_cnn)
y_pred_best_classes = np.argmax(y_pred_best, axis=1)
y_true_best_classes = np.argmax(y_test, axis=1)
# Out:
# Trial 90 Complete [00h 00m 06s]
# val_accuracy: 0.6666666865348816
#
# Best val_accuracy So Far: 0.8333333134651184
# Total elapsed time: 00h 05m 50s
# Best Hyperparameters:
# Filters in Layer 1: 128
# Kernel Size in Layer 1: 5
# Dropout in Layer 1: 0.4
# Filters in Layer 2: 32
# Kernel Size in Layer 2: 5
# Dropout in Layer 2: 0.2
# Units in Dense Layer 1: 128
# Dropout in Dense Layer 1: 0.3
# Units in Dense Layer 2: 32
# Dropout in Dense Layer 2: 0.3
# Learning Rate: 0.01
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.4502 - loss: 2.2559 - val_accuracy: 0.5000 - val_loss: 1.9598
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5747 - loss: 2.0169 - val_accuracy: 0.4167 - val_loss: 1.8572
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6223 - loss: 1.7707 - val_accuracy: 0.4167 - val_loss: 1.7640
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6535 - loss: 1.6731 - val_accuracy: 0.3333 - val_loss: 1.6775
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6889 - loss: 1.5812 - val_accuracy: 0.5000 - val_loss: 1.5994
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7926 - loss: 1.4166 - val_accuracy: 0.5833 - val_loss: 1.5225
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7428 - loss: 1.2901 - val_accuracy: 0.5833 - val_loss: 1.4464
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7074 - loss: 1.2083 - val_accuracy: 0.5000 - val_loss: 1.3802
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9108 - loss: 1.0551 - val_accuracy: 0.5000 - val_loss: 1.3265
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8071 - loss: 1.0295 - val_accuracy: 0.5000 - val_loss: 1.2787
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8714 - loss: 0.8967 - val_accuracy: 0.5833 - val_loss: 1.2384
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8859 - loss: 0.8610 - val_accuracy: 0.5833 - val_loss: 1.1959
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9357 - loss: 0.8030 - val_accuracy: 0.5000 - val_loss: 1.1563
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8610 - loss: 0.7678 - val_accuracy: 0.5833 - val_loss: 1.1159
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8569 - loss: 0.7431 - val_accuracy: 0.4167 - val_loss: 1.0838
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9108 - loss: 0.6563 - val_accuracy: 0.5833 - val_loss: 1.0358
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9316 - loss: 0.6134 - val_accuracy: 0.5833 - val_loss: 1.0175
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9751 - loss: 0.5133 - val_accuracy: 0.5000 - val_loss: 1.0175
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9212 - loss: 0.6179 - val_accuracy: 0.5833 - val_loss: 1.0294
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9212 - loss: 0.6321 - val_accuracy: 0.5000 - val_loss: 1.0124
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9253 - loss: 0.5763 - val_accuracy: 0.7500 - val_loss: 0.9508
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9108 - loss: 0.4543 - val_accuracy: 0.7500 - val_loss: 0.9146
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9357 - loss: 0.4812 - val_accuracy: 0.7500 - val_loss: 0.8978
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8755 - loss: 0.7182 - val_accuracy: 0.7500 - val_loss: 0.8832
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9751 - loss: 0.3918 - val_accuracy: 0.6667 - val_loss: 0.8902
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9253 - loss: 0.4557 - val_accuracy: 0.5833 - val_loss: 0.9041
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9710 - loss: 0.4008 - val_accuracy: 0.5833 - val_loss: 0.9046
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9357 - loss: 0.3976 - val_accuracy: 0.5833 - val_loss: 0.8982
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9502 - loss: 0.3614 - val_accuracy: 0.5000 - val_loss: 0.8939
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9606 - loss: 0.3482 - val_accuracy: 0.6667 - val_loss: 0.8921
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9751 - loss: 0.3253 - val_accuracy: 0.6667 - val_loss: 0.9044
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9502 - loss: 0.3315 - val_accuracy: 0.6667 - val_loss: 0.9028
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9751 - loss: 0.2777 - val_accuracy: 0.6667 - val_loss: 0.9068
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9751 - loss: 0.2688 - val_accuracy: 0.6667 - val_loss: 0.9080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step

# %%
print("Classification Report:")
print(classification_report(y_true_best_classes, y_pred_best_classes))

accuracy = accuracy_score(y_true_best_classes, y_pred_best_classes)
roc_auc = roc_auc_score(y_test, y_pred_best, multi_class='ovr', average='weighted')
precision = precision_score(y_true_best_classes, y_pred_best_classes, average='macro')
recall = recall_score(y_true_best_classes, y_pred_best_classes, average='macro')
f1 = f1_score(y_true_best_classes, y_pred_best_classes, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.80      0.67      0.73         6
#
#     accuracy                           0.75        12
#    macro avg       0.76      0.75      0.75        12
# weighted avg       0.76      0.75      0.75        12
#
# Accuracy: 0.75
# ROC-AUC Score: 0.72
# Precision: 0.76
# Recall: 0.75
# F1-Score: 0.75

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true_best_classes, y_pred_best_classes)

plt.figure(figsize=(10, 8))
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_best[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, 
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves Graph')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred_best[:, i])
    avg_precision = average_precision_score(y_test[:, i], y_pred_best[:, i])
    plt.plot(recall, precision, lw=2,
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AP = {avg_precision:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 21, 128)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 21, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 8, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 8, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 200,840 (784.54 KB)
#  Trainable params: 66,818 (261.01 KB)
#  Non-trainable params: 384 (1.50 KB)
#  Optimizer params: 133,638 (522.03 KB)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 19, 128)        │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 19, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 9, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 9, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 5, 32)          │        20,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 5, 32)          │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 2, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 2, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 102,664 (401.04 KB)
#  Trainable params: 34,114 (133.26 KB)
#  Non-trainable params: 320 (1.25 KB)
#  Optimizer params: 68,230 (266.53 KB)

# %%
import shap

subset_data = x_test_cnn

explainer = shap.DeepExplainer(model, subset_data)

shap_values = explainer.shap_values(subset_data)
# Out:
# c:\Users\kahch\anaconda3\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(12, 23, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(24, 23, 1))']
#   warnings.warn(msg)

# %%
feature_names = data.drop(columns=['subject_id', 'label_sleep']).columns.tolist()
expected_value = explainer.expected_value[0].numpy()

shap.plots.waterfall(
    shap.Explanation(
        values=shap_values[0, :, 0, 0],
        base_values=expected_value,
        data=subset_data[0].flatten(),
        feature_names=feature_names
    ),
)
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.

# %%
shap.initjs()
subset_data_reshaped = subset_data.reshape(subset_data.shape[0], subset_data.shape[1])

shap.plots.force(
    expected_value,
    shap_values[:, :, 0, 0],
    subset_data_reshaped,
    feature_names=feature_names
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iYZSH7TE46MW09R5VQLVP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.38237354159355164, "link": "identity", "featureNames": ["label_first_scenario", "label_time_exp", "period", "TO_Decision_Rural", "TO_RT_Rural", "TO_MaxSWA_Rural", "TO_ReengageTime_Rural", "TO_MaxBraking_Rural", "TO_Decision_Urban", "TO_RT_Urban", "TO_MaxSWA_Urban", "TO_ReengageTime_Urban", "TO_MaxBraking_Urban", "time_experiment", "RT_0_City", "RT_1_City", "RT_2_City", "RT_3_City", "RT_0_Country", "RT_1_Country", "RT_2_Country", "RT_3_Country", "RT_4_Country"], "explanations": [{"outValue": 0.5773908347273482, "simIndex": 5.0, "features": {"0": {"effect": -0.0012450926454845143, "value": -1.0910894511799616}, "1": {"effect": 0.008513550059754066, "value": 0.8017837257372732}, "2": {"effect": 0.0, "value": 0.0}, "3": {"effect": 0.022192028358065847, "value": -1.0220970289135212}, "4": {"effect": -0.000998122882322181, "value": -0.20307782007206088}, "5": {"effect": 0.007954232330873189, "value": -0.49233288302173084}, "6": {"effect": 0.028337586842786384, "value": -0.24597804614743163}, "7": {"effect": 0.006453155175433275, "value": 0.3106119091159555}, "8": {"effect": -0.018393210635688512, "value": -1.1530401452384142}, "9": {"effect": -0.006409217374523663, "value": -0.7645429418203944}, "10": {"effect": 0.021363347655554848, "value": -0.49721785083070136}, "11": {"effect": 0.051237915305876625, "value": -0.6872201742960512}, "12": {"effect": -0.0012849231310138162, "value": 0.485757619860025}, "13": {"effect": 0.025879746120867773, "value": 0.8017837257372732}, "14": {"effect": 0.01346498689723536, "value": -0.6025640217059891}, "15": {"effect": 0.01830072682240669, "value": -0.9207757335956918}, "16": {"effect": 0.01132746290381705, "value": -0.5515511296640875}, "17": {"effect": 0.0008382811225293797, "value": -0.2738688893744802}, "18": {"effect": -4.656798117004443e-05, "value": -0.3021738255011153}, "19": {"effect": 0.00955773678195722, "value": 1.8895665046978536}, "20": {"effect": -0.0018432788648216237, "value": 0.3753080638848779}, "21": {"effect": -0.00018304972833678654, "value": -0.5471817231196086}, "22": {"effect": 0.0, "value": -0.6996798894038929}}}, {"outValue": 0.4478657500557756, "simIndex": 6.0, "features": {"0": {"effect": 0.0011043444350627585, "value": 0.9165151389911678}, "1": {"effect": -0.005885137936234398, "value": 0.8017837257372732}, "2": {"effect": 0.0, "value": 0.0}, "3": {"effect": -0.004054576936571851, "value": 1.0831177470576123}, "4": {"effect": -0.0031623101024125344, "value": -0.7806833596379456}, "5": {"effect": 0.009578121925146798, "value": -0.41333062969963913}, "6": {"effect": 0.018459579827378978, "value": -0.10961309179772737}, "7": {"effect": 0.008095949582795506, "value": 0.3106119091159555}, "8": {"effect": -0.023985734452591927, "value": -1.1530401452384142}, "9": {"effect": 0.028265623348483787, "value": 0.6383517053384838}, "10": {"effect": 0.014922970572392334, "value": -0.1337872757930359}, "11": {"effect": 0.022126800381349804, "value": 0.2246327872696081}, "12": {"effect": -0.001496740664252507, "value": 0.485757619860025}, "13": {"effect": -0.005754656448857788, "value": 0.8017837257372732}, "14": {"effect": 0.005699144435631951, "value": 0.18620094926643202}, "15": {"effect": 0.0038952043304002868, "value": -0.4636759603564875}, "16": {"effect": -0.00910866279284635, "value": 0.22144022255847884}, "17": {"effect": 0.0006536584394563641, "value": -0.2814454646366049}, "18": {"effect": 0.00792509812787943, "value": 1.1263499670544819}, "19": {"effect": 0.00030802560047117725, "value": -0.3408885623112364}, "20": {"effect": -0.00040758080423815545, "value": -0.3117545600117547}, "21": {"effect": -0.0016869124062196736, "value": -0.49623019183334266}, "22": {"effect": 0.0, "value": 0.08139503320478872}}}, {"outValue": 0.3731375669570364, "simIndex": 8.0, "features": {"0": {"effect": -0.004992745158996557, "value": -1.0910894511799616}, "1": {"effect": 0.00148128559445912 ...

# %%
shap.summary_plot(
    shap_values[:, :, 0, 0],
    subset_data_reshaped,
    feature_names=feature_names
)

# %%
shap_exp = shap.Explanation(
    values=shap_values[:, :, 0, 0],
    base_values=expected_value,
    data=subset_data_reshaped,
    feature_names=feature_names
)

shap.plots.beeswarm(shap_exp)

# %%
shap.plots.bar(
    shap.Explanation(
        values=shap_values[0, :, 0, 0],
        base_values=expected_value,
        data=subset_data[0].flatten(),
        feature_names=feature_names
    )
)

# %%
pip install quantus
# Out:
# Requirement already satisfied: quantus in c:\users\kahch\anaconda3\lib\site-packages (0.5.3)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.26.4)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (2.2.2)
# Requirement already satisfied: opencv-python>=4.5.5.62 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (4.11.0.86)
# Requirement already satisfied: scikit-image>=0.19.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (0.24.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.5.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.13.1)
# Requirement already satisfied: tqdm>=4.62.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (4.66.5)
# Requirement already satisfied: matplotlib>=3.3.4 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kahch\anaconda3\lib\site-packages (from pandas>=1.5.3->quantus) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kahch\anaconda3\lib\site-packages (from pandas>=1.5.3->quantus) (2023.3)
# Requirement already satisfied: networkx>=2.8 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (3.3)
# Requirement already satisfied: imageio>=2.33 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->quantus) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->quantus) (3.5.0)
# Requirement already satisfied: colorama in c:\users\kahch\anaconda3\lib\site-packages (from tqdm>=4.62.3->quantus) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kahch\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->quantus) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)

# %%
import quantus

def shap_explain_func(model, inputs, targets, **kwargs):

    if inputs.ndim == 3 and inputs.shape[1] == 1:
        inputs_reshaped = np.transpose(inputs, (0, 2, 1))
    else:
        inputs_reshaped = inputs

    background = inputs_reshaped[:100]

    explainer = shap.DeepExplainer(model, background)

    shap_values = explainer.shap_values(inputs_reshaped)

    explanations = shap_values[:, :, 0, 0]
    
    return explanations

def evaluate_xai_metrics(x_batch: np.ndarray, y_batch: np.ndarray, 
                        attributions: np.ndarray, n_samples):
    
    x_batch = x_batch[:n_samples]
    y_batch = y_batch[:n_samples]
    attributions = attributions[:n_samples]

    metrics = {
        "robustness": quantus.AvgSensitivity(
            nr_samples=2,
            lower_bound=0.2,
            norm_numerator=quantus.norm_func.fro_norm,
            norm_denominator=quantus.norm_func.fro_norm,
            perturb_func=quantus.perturb_func.uniform_noise,
            similarity_func=quantus.similarity_func.difference,
            abs=True,
            normalise=False,
            aggregate_func=np.mean,
            return_aggregate=True,
            disable_warnings=True,
            display_progressbar=True,
        ),
        "complexity": quantus.Sparseness(
            abs=True,
            normalise=True,
            disable_warnings=True,
            display_progressbar=True,
            return_aggregate=True,
        ),
        "randomisation": quantus.MPRT(
            similarity_func=quantus.similarity_func.correlation_spearman,
            return_average_correlation=True,
            aggregate_func=np.mean,
            layer_order="independent",
            disable_warnings=True,
            normalise=True,
            abs=True,
            display_progressbar=True,
        )
    }

    results = {}
    for metric_name, metric in metrics.items():
        score = metric(
            model=model,
            x_batch=x_batch,
            y_batch=y_batch,
            a_batch=attributions,
            explain_func=shap_explain_func
        )
        score_value = np.mean(score) if isinstance(score, (np.ndarray, list)) else score
            
        results[metric_name] = score_value
        print(f"{metric_name.capitalize()} Score: {score_value:.4f}")
    
    return results

def plot_metric_results(results):
    results = {k: v for k, v in results.items() if v is not None}
        
    plt.figure(figsize=(10, 6))
    metrics = list(results.keys())
    scores = list(results.values())
    
    bars = plt.bar(metrics, scores)
    plt.title('XAI Evaluation Metrics')
    plt.xticks(rotation=45)
    plt.ylabel('Score')
    
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.4f}',
                ha='center', va='bottom')
    
    plt.tight_layout()
    plt.show()


y_test_classes = np.argmax(y_test, axis=1)

results = evaluate_xai_metrics(
    x_batch=x_test_cnn,
    y_batch=y_test_classes,
    attributions=shap_values[:, :, 0, 0],
    n_samples=100
)

plot_metric_results(results)
# Out:
#   0%|          | 0/1.0 [00:00<?, ?it/s]
# c:\Users\kahch\anaconda3\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(12, 23, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(24, 23, 1))']
#   warnings.warn(msg)
# Robustness Score: 0.2111
#   0%|          | 0/1.0 [00:00<?, ?it/s]
# Complexity Score: 0.6187
#   0%|          | 0/84 [00:00<?, ?it/s]
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer
# Received: inputs=['Tensor(shape=(12, 23, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer
# Received: inputs=['Tensor(shape=(24, 23, 1))']
#   warnings.warn(msg)
# Randomisation Score: 0.7425
