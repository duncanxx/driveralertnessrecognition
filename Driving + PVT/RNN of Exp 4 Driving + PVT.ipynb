# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# physio_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/Physio/periods/features_segm_1.csv"
# driving_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/Driving/features_tor_10s_30s_rows.csv"
# pvt_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/PVT/data_PVT_no_outliers_mean_sd.csv"

# %%
driving_path = "../Exp4/Preprocessed/Driving/features_tor_10s_30s_rows.csv"
pvt_path = "../Exp4/Preprocessed/PVT/data_PVT_no_outliers_mean_sd.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

driving_data = pd.read_csv(driving_path)
pvt_data = pd.read_csv(pvt_path)

# merge two datasets follow by "subject_id"
# inner is used to make sure both dataset include the subject id only to be input into the data
data = pd.merge(driving_data, pvt_data, on='subject_id', how='inner')

print(data.shape)
# Out:
# (58, 29)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   subject_id             58 non-null     int64
#  1   label_sleep            58 non-null     int64
#  2   label_first_scenario   58 non-null     object
#  3   label_time_exp         58 non-null     int64
#  4   period                 58 non-null     object
#  5   TO_Decision_Rural      58 non-null     int64
#  6   TO_RT_Rural            58 non-null     float64
#  7   TO_MaxSWA_Rural        58 non-null     float64
#  8   TO_ReengageTime_Rural  40 non-null     float64
#  9   TO_MaxBraking_Rural    58 non-null     float64
#  10  TO_Decision_Urban      49 non-null     float64
#  11  TO_RT_Urban            49 non-null     float64
#  12  TO_MaxSWA_Urban        49 non-null     float64
#  13  TO_ReengageTime_Urban  39 non-null     float64
#  14  TO_MaxBraking_Urban    49 non-null     float64
#  15  code                   58 non-null     object
#  16  sleep_condition        58 non-null     int64
#  17  time_experiment        58 non-null     int64
#  18  first_scenario         58 non-null     object
#  19  RT_0_City              56 non-null     float64
#  20  RT_1_City              55 non-null     float64
#  21  RT_2_City              50 non-null     float64
#  22  RT_3_City              48 non-null     float64
#  23  RT_4_City              19 non-null     float64
#  24  RT_0_Country           55 non-null     float64
#  25  RT_1_Country           52 non-null     float64
#  26  RT_2_Country           57 non-null     float64
#  27  RT_3_Country           57 non-null     float64
#  28  RT_4_Country           56 non-null     float64
# dtypes: float64(19), int64(6), object(4)
# memory usage: 13.3+ KB

# %%
data.head()
# Out:
#    subject_id  label_sleep label_first_scenario  label_time_exp   period  \
# 0           1            0          Countryside              16  Country
# 1           2            1                Urban              16  Country
# 2           3            0          Countryside              16  Country
# 3           4            1          Countryside              16  Country
# 4           5            0          Countryside              10  Country
#
#    TO_Decision_Rural  TO_RT_Rural  TO_MaxSWA_Rural  TO_ReengageTime_Rural  \
# 0                  1        2.450              5.0                 12.399
# 1                  4        2.900              2.0                  3.233
# 2                  1        2.233              7.0                 25.767
# 3                  4        1.665             37.0                    NaN
# 4                  1        1.467              6.0                  3.750
#
#    TO_MaxBraking_Rural  ...  RT_0_City  RT_1_City  RT_2_City  RT_3_City  \
# 0                100.0  ...   1.081116   0.822021   1.106934   1.363037
# 1                  0.0  ...   0.954437   2.314331        NaN        NaN
# 2                100.0  ...   1.022156   1.008484   1.222046   1.314209
# 3                100.0  ...   1.710815   1.583008   1.559570   1.510010
# 4                100.0  ...   1.815369   1.424805        NaN        NaN
#
#    RT_4_City RT_0_Country  RT_1_Country  RT_2_Country RT_3_Country  \
# 0        NaN     1.299316      3.667419      2.049561     1.050903
# 1        NaN     0.749969      1.362122      1.615845          NaN
# 2   0.899292     0.726898      1.000244      0.831909     1.666626
# 3        NaN     1.700867           NaN      1.499390     1.400513
# 4        NaN     1.666779      1.383423      1.466309     1.500610
#
#    RT_4_Country
# 0      0.699707
# 1      1.899658
# 2      0.900024
# 3      1.433350
# 4      1.433350
#
# [5 rows x 29 columns]

# %%
label_counts = data["label_sleep"].value_counts()
print(label_counts)
# Out:
# label_sleep
# 1    31
# 0    27
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")
plt.title("Class Distribution: label_sleep")
plt.xlabel("Classes")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\kahch\AppData\Local\Temp\ipykernel_57756\3141730654.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")

# %%
columns_to_drop = ["sleep_condition", "code", "first_scenario"]
data = data.drop(columns=columns_to_drop, axis=1)

# %% [markdown]
# #Data Preprocessing

# %%
columns_to_exclude = data.columns[data.isnull().mean() > 0.5]
data = data.drop(columns=columns_to_exclude)

data.replace([np.inf, -np.inf], np.nan, inplace=True)

numerical_data = data.select_dtypes(include=['number'])

missing_values = numerical_data.isnull().sum()
print("Missing Values:\n", missing_values[missing_values > 0])

data.fillna(numerical_data.mean(), inplace=True)

missing_after = data.isnull().sum()
print("\nMissing Values After Filling:\n", missing_after[missing_after > 0])

if missing_after.sum() == 0:
    print("\nAll missing values have been successfully filled!")
else:
    print("\nThere are still missing values in the dataset.")
# Out:
# Missing Values:
#  TO_ReengageTime_Rural    18
# TO_Decision_Urban         9
# TO_RT_Urban               9
# TO_MaxSWA_Urban           9
# TO_ReengageTime_Urban    19
# TO_MaxBraking_Urban       9
# RT_0_City                 2
# RT_1_City                 3
# RT_2_City                 8
# RT_3_City                10
# RT_0_Country              3
# RT_1_Country              6
# RT_2_Country              1
# RT_3_Country              1
# RT_4_Country              2
# dtype: int64
#
# Missing Values After Filling:
#  Series([], dtype: int64)
#
# All missing values have been successfully filled!

# %%
data["label_first_scenario"] = data["label_first_scenario"].map({"Countryside": 0, "Urban": 1})
data["period"] = data["period"].map({"Country": 0, "Urban": 1})

print("\n'label_first_scenario' Column After Encoding:\n", data["label_first_scenario"].head())
print("\n'period' Column After Encoding:\n", data["period"].head())
# Out:
# 'label_first_scenario' Column After Encoding:
#  0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: label_first_scenario, dtype: int64
#
# 'period' Column After Encoding:
#  0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: period, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data["label_sleep"] = label_encoder.fit_transform(data["label_sleep"])

print("Encoded Labels:\n", data["label_sleep"].unique())
# Out:
# Encoded Labels:
#  [0 1]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, precision_score, recall_score, f1_score

X = data.drop(columns=['subject_id', 'label_sleep']).values
y = data['label_sleep'].values

encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y.reshape(-1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

print(f"Training Set Size: {x_train.shape}")
print(f"Testing Set Size: {x_test.shape}")

scaler = StandardScaler()
x_train_norm = scaler.fit_transform(x_train)
x_test_norm = scaler.transform(x_test)
# Out:
# Training Set Size: (46, 23)
# Testing Set Size: (12, 23)

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y), y=y)
class_weights_dict = dict(enumerate(class_weights))

x_train_rnn = x_train_norm.reshape(x_train_norm.shape[0], x_train_norm.shape[1], 1)
x_test_rnn = x_test_norm.reshape(x_test_norm.shape[0], x_test_norm.shape[1], 1)

input_size = x_train_norm.shape[1]
output_size = y_train.shape[1]

model = models.Sequential([
    layers.SimpleRNN(64, activation='tanh', return_sequences=True, input_shape=(x_train_rnn.shape[1], 1)),
    layers.Dropout(0.3),

    layers.SimpleRNN(32, activation='tanh', return_sequences=False),
    layers.Dropout(0.3),

    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.4),

    layers.Dense(y_train.shape[1], activation='sigmoid')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

history = model.fit(
    x_train_rnn, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(x_test_rnn, y_test),
    class_weight=class_weights_dict,
    callbacks=[early_stopping],
    verbose=1
)

val_loss, val_accuracy = model.evaluate(x_test_rnn, y_test, verbose=0)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

y_pred = model.predict(x_test_rnn)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)
# Out:
# Epoch 1/100
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - accuracy: 0.5394 - loss: 1.1511 - val_accuracy: 0.5833 - val_loss: 1.1258
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5996 - loss: 1.1141 - val_accuracy: 0.6667 - val_loss: 1.1009
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4647 - loss: 1.1500 - val_accuracy: 0.7500 - val_loss: 1.0800
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5457 - loss: 1.1222 - val_accuracy: 0.7500 - val_loss: 1.0564
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5498 - loss: 1.0852 - val_accuracy: 0.7500 - val_loss: 1.0398
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7138 - loss: 1.0576 - val_accuracy: 0.7500 - val_loss: 1.0268
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6037 - loss: 1.0923 - val_accuracy: 0.6667 - val_loss: 1.0151
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5684 - loss: 1.0585 - val_accuracy: 0.6667 - val_loss: 1.0060
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6576 - loss: 1.0099 - val_accuracy: 0.6667 - val_loss: 0.9985
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7428 - loss: 1.0197 - val_accuracy: 0.6667 - val_loss: 0.9947
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6576 - loss: 0.9797 - val_accuracy: 0.6667 - val_loss: 0.9922
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6825 - loss: 1.0339 - val_accuracy: 0.6667 - val_loss: 0.9850
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6286 - loss: 0.9770 - val_accuracy: 0.7500 - val_loss: 0.9780
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7178 - loss: 0.9885 - val_accuracy: 0.6667 - val_loss: 0.9720
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7097 - loss: 0.9501 - val_accuracy: 0.6667 - val_loss: 0.9663
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7242 - loss: 0.9593 - val_accuracy: 0.6667 - val_loss: 0.9576
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7219 - loss: 0.9683 - val_accuracy: 0.6667 - val_loss: 0.9483
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7178 - loss: 0.9357 - val_accuracy: 0.6667 - val_loss: 0.9403
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7178 - loss: 0.9299 - val_accuracy: 0.6667 - val_loss: 0.9309
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7572 - loss: 0.9624 - val_accuracy: 0.6667 - val_loss: 0.9193
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7364 - loss: 0.9378 - val_accuracy: 0.7500 - val_loss: 0.9069
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6599 - loss: 0.9117 - val_accuracy: 0.7500 - val_loss: 0.8972
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7387 - loss: 0.8825 - val_accuracy: 0.7500 - val_loss: 0.8913
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7219 - loss: 0.8747 - val_accuracy: 0.7500 - val_loss: 0.8899
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8175 - loss: 0.8274 - val_accuracy: 0.7500 - val_loss: 0.8901
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7428 - loss: 0.8548 - val_accuracy: 0.7500 - val_loss: 0.8889
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8465 - loss: 0.8406 - val_accuracy: 0.7500 - val_loss: 0.8870
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6784 - loss: 0.8979 - val_accuracy: 0.7500 - val_loss: 0.8860
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7822 - loss: 0.8612 - val_accuracy: 0.7500 - val_loss: 0.8833
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8071 - loss: 0.8426 - val_accuracy: 0.8333 - val_loss: 0.8678
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7677 - loss: 0.8548 - val_accuracy: 0.8333 - val_loss: 0.8587
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8279 - loss: 0.7985 - val_accuracy: 0.7500 - val_loss: 0.8419
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8279 - loss: 0.7866 - val_accuracy: 0.7500 - val_loss: 0.8376
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8610 - loss: 0.7617 - val_accuracy: 0.7500 - val_loss: 0.8358
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8569 - loss: 0.6903 - val_accuracy: 0.7500 - val_loss: 0.8379
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7966 - loss: 0.7516 - val_accuracy: 0.7500 - val_loss: 0.8371
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8216 - loss: 0.7285 - val_accuracy: 0.7500 - val_loss: 0.8371
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8755 - loss: 0.7053 - val_accuracy: 0.6667 - val_loss: 0.8381
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9067 - loss: 0.6621 - val_accuracy: 0.7500 - val_loss: 0.8265
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8320 - loss: 0.7206 - val_accuracy: 0.8333 - val_loss: 0.8009
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8216 - loss: 0.7034 - val_accuracy: 0.8333 - val_loss: 0.7757
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8216 - loss: 0.6979 - val_accuracy: 0.9167 - val_loss: 0.7614
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8610 - loss: 0.6808 - val_accuracy: 0.9167 - val_loss: 0.7566
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9108 - loss: 0.6128 - val_accuracy: 0.9167 - val_loss: 0.7510
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8505 - loss: 0.6364 - val_accuracy: 0.8333 - val_loss: 0.7466
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9461 - loss: 0.5585 - val_accuracy: 0.8333 - val_loss: 0.7506
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8963 - loss: 0.6289 - val_accuracy: 0.8333 - val_loss: 0.7636
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8859 - loss: 0.5726 - val_accuracy: 0.7500 - val_loss: 0.7772
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8465 - loss: 0.5903 - val_accuracy: 0.7500 - val_loss: 0.7839
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8610 - loss: 0.5998 - val_accuracy: 0.8333 - val_loss: 0.7786
# Validation Accuracy: 83.33%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step

# %%
print("Classification Report:\n")
print(classification_report(y_true_classes, y_pred_classes))

accuracy = accuracy_score(y_true_classes, y_pred_classes)
if y_test.shape[1] == 2:
    roc_auc = roc_auc_score(y_true_classes, y_pred[:, 1])
else:
    roc_auc = roc_auc_score(y_test, y_pred, multi_class='ovr', average='weighted')

precision = precision_score(y_true_classes, y_pred_classes, average='macro')
recall = recall_score(y_true_classes, y_pred_classes, average='macro')
f1 = f1_score(y_true_classes, y_pred_classes, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         6
#            1       0.75      1.00      0.86         6
#
#     accuracy                           0.83        12
#    macro avg       0.88      0.83      0.83        12
# weighted avg       0.88      0.83      0.83        12
#
# Accuracy: 0.83
# ROC-AUC Score: 0.83
# Precision: 0.88
# Recall: 0.83
# F1-Score: 0.83

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(10, 8))
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc, average_precision_score

plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, 
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves Graph')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred[:, i])
    avg_precision = average_precision_score(y_test[:, i], y_pred[:, i])
    plt.plot(recall, precision, lw=2,
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AP = {avg_precision:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\kahch\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (2.1.0)
# Requirement already satisfied: numpy in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (13.7.1)
# Requirement already satisfied: namex in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kahch\anaconda3\lib\site-packages (from optree->keras->keras-tuner) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kahch\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kahch\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kahch\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)

# %%
import keras_tuner as kt

def build_rnn_model(hp):
    input_size = x_train_rnn.shape[1]
    output_size = y_train.shape[1]

    model = models.Sequential()

    model.add(layers.SimpleRNN(
        units=hp.Choice('rnn_units_1', values=[32, 64]),
        activation='tanh',
        return_sequences=True,
        input_shape=(input_size, 1),
        kernel_regularizer=regularizers.l2(0.01)
    ))

    model.add(layers.Dropout(hp.Choice('dropout_1', values=[0.3, 0.4])))

    model.add(layers.SimpleRNN(
        units=hp.Choice('rnn_units_2', values=[16, 32]),
        activation='tanh',
        return_sequences=False,
        kernel_regularizer=regularizers.l2(0.01)
    ))

    model.add(layers.Dense(
        units=hp.Choice('dense_units_1', values=[32, 64]),
        activation='relu',
        kernel_regularizer=regularizers.l2(0.02)
    ))
    model.add(layers.Dropout(hp.Choice('dropout_2', values=[0.3, 0.4])))

    model.add(layers.Dense(output_size, activation='sigmoid'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Choice('learning_rate', values=[0.001, 0.005])
        ),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

tuner = kt.Hyperband(
    build_rnn_model,
    objective='val_accuracy',
    max_epochs=50,
    factor=3,
    directory='RNN_tuning',
    project_name='RNN_Hyperparameter_Tuning'
)

hyper_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

tuner.search(
    x_train_rnn, y_train,
    validation_data=(x_test_rnn, y_test),
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[hyper_early_stopping],
    verbose=1
)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:")
print(f"RNN Layer 1 Units: {best_hps.get('rnn_units_1')}")
print(f"RNN Layer 2 Units: {best_hps.get('rnn_units_2')}")
print(f"Dropout in Layer 1: {best_hps.get('dropout_1')}")
print(f"Dropout in Dense Layer 1: {best_hps.get('dropout_2')}")
print(f"Dense Layer 1 Units: {best_hps.get('dense_units_1')}")
print(f"Learning Rate: {best_hps.get('learning_rate')}")

best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(
    x_train_rnn, y_train,
    validation_data=(x_test_rnn, y_test),
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[hyper_early_stopping],
    verbose=1
)

val_loss, val_accuracy = best_model.evaluate(x_test_rnn, y_test, verbose=0)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

y_pred_best = best_model.predict(x_test_rnn)
y_pred_best_classes = np.argmax(y_pred_best, axis=1)
y_true_best_classes = np.argmax(y_test, axis=1)
# Out:
# Trial 85 Complete [00h 00m 07s]
# val_accuracy: 0.9166666865348816
#
# Best val_accuracy So Far: 0.9166666865348816
# Total elapsed time: 00h 05m 38s
# Best Hyperparameters:
# RNN Layer 1 Units: 64
# RNN Layer 2 Units: 16
# Dropout in Layer 1: 0.4
# Dropout in Dense Layer 1: 0.3
# Dense Layer 1 Units: 64
# Learning Rate: 0.005
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.3963 - loss: 1.4808 - val_accuracy: 0.5000 - val_loss: 1.3754
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5353 - loss: 1.3907 - val_accuracy: 0.5000 - val_loss: 1.3433
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5747 - loss: 1.3274 - val_accuracy: 0.6667 - val_loss: 1.3055
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5643 - loss: 1.2766 - val_accuracy: 0.6667 - val_loss: 1.2656
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6929 - loss: 1.1968 - val_accuracy: 0.7500 - val_loss: 1.1753
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7926 - loss: 1.1228 - val_accuracy: 0.7500 - val_loss: 1.1240
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7178 - loss: 1.1026 - val_accuracy: 0.6667 - val_loss: 1.1121
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6182 - loss: 1.0964 - val_accuracy: 0.7500 - val_loss: 1.0028
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7034 - loss: 1.0209 - val_accuracy: 0.5833 - val_loss: 1.0327
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6431 - loss: 0.9826 - val_accuracy: 0.8333 - val_loss: 0.9286
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7219 - loss: 0.9397 - val_accuracy: 0.7500 - val_loss: 0.8943
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8424 - loss: 0.8517 - val_accuracy: 0.7500 - val_loss: 0.8696
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9067 - loss: 0.7598 - val_accuracy: 0.6667 - val_loss: 0.9172
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8216 - loss: 0.7965 - val_accuracy: 0.8333 - val_loss: 0.8088
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8361 - loss: 0.7534 - val_accuracy: 0.6667 - val_loss: 0.8062
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8963 - loss: 0.7286 - val_accuracy: 0.6667 - val_loss: 0.7959
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8610 - loss: 0.6421 - val_accuracy: 0.6667 - val_loss: 0.8068
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8134 - loss: 0.5979 - val_accuracy: 0.7500 - val_loss: 0.7342
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9108 - loss: 0.5678 - val_accuracy: 0.5833 - val_loss: 0.9251
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8569 - loss: 0.5660 - val_accuracy: 0.5833 - val_loss: 0.9445
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8465 - loss: 0.6000 - val_accuracy: 0.6667 - val_loss: 0.9031
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9357 - loss: 0.4128 - val_accuracy: 0.7500 - val_loss: 0.7404
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7677 - loss: 0.5967 - val_accuracy: 0.7500 - val_loss: 0.7147
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9502 - loss: 0.4598 - val_accuracy: 0.7500 - val_loss: 0.7861
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9606 - loss: 0.4078 - val_accuracy: 0.7500 - val_loss: 0.8437
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9502 - loss: 0.3555 - val_accuracy: 0.7500 - val_loss: 0.9540
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8610 - loss: 0.5020 - val_accuracy: 0.7500 - val_loss: 0.9767
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9357 - loss: 0.3614 - val_accuracy: 0.5833 - val_loss: 1.2322
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8505 - loss: 0.5470 - val_accuracy: 0.6667 - val_loss: 0.7307
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9004 - loss: 0.4411 - val_accuracy: 0.7500 - val_loss: 0.7318
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8714 - loss: 0.4339 - val_accuracy: 0.8333 - val_loss: 0.6010
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9606 - loss: 0.3568 - val_accuracy: 0.8333 - val_loss: 0.6829
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9751 - loss: 0.3348 - val_accuracy: 0.8333 - val_loss: 0.6559
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9108 - loss: 0.3821 - val_accuracy: 0.8333 - val_loss: 0.6455
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9751 - loss: 0.3213 - val_accuracy: 0.6667 - val_loss: 0.7224
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9253 - loss: 0.3245 - val_accuracy: 0.6667 - val_loss: 0.8045
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9606 - loss: 0.2255 - val_accuracy: 0.8333 - val_loss: 0.8030
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9461 - loss: 0.2541 - val_accuracy: 0.8333 - val_loss: 0.8316
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.2099 - val_accuracy: 0.6667 - val_loss: 1.2154
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9420 - loss: 0.3143 - val_accuracy: 0.5833 - val_loss: 1.0544
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9855 - loss: 0.2295 - val_accuracy: 0.7500 - val_loss: 0.7332
# Validation Accuracy: 83.33%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step

# %%
print("Classification Report:")
print(classification_report(y_true_best_classes, y_pred_best_classes))

accuracy = accuracy_score(y_true_best_classes, y_pred_best_classes)
roc_auc = roc_auc_score(y_test, y_pred_best, multi_class='ovr', average='weighted')
precision = precision_score(y_true_best_classes, y_pred_best_classes, average='macro')
recall = recall_score(y_true_best_classes, y_pred_best_classes, average='macro')
f1 = f1_score(y_true_best_classes, y_pred_best_classes, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         6
#            1       0.75      1.00      0.86         6
#
#     accuracy                           0.83        12
#    macro avg       0.88      0.83      0.83        12
# weighted avg       0.88      0.83      0.83        12
#
# Accuracy: 0.83
# ROC-AUC Score: 0.86
# Precision: 0.88
# Recall: 0.83
# F1-Score: 0.83

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true_best_classes, y_pred_best_classes)

plt.figure(figsize=(10, 8))
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_best[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, 
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves Graph')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred_best[:, i])
    avg_precision = average_precision_score(y_test[:, i], y_pred_best[:, i])
    plt.plot(recall, precision, lw=2,
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AP = {avg_precision:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 23, 64)         │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 32)             │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,712 (112.16 KB)
#  Trainable params: 9,570 (37.38 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 19,142 (74.78 KB)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_2 (SimpleRNN)        │ (None, 23, 64)         │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 23, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 16)             │         1,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,216 (78.97 KB)
#  Trainable params: 6,738 (26.32 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 13,478 (52.65 KB)
