# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# physio_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/Physio/periods/features_segm_1.csv"
# driving_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/Driving/features_tor_10s_30s_rows.csv"
# pvt_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/PVT/data_PVT_no_outliers_mean_sd.csv"

# %%
driving_path = "../Exp4/Preprocessed/Driving/features_tor_10s_30s_rows.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(driving_path)

print(data.shape)
# Out:
# (58, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   subject_id             58 non-null     int64
#  1   label_sleep            58 non-null     int64
#  2   label_first_scenario   58 non-null     object
#  3   label_time_exp         58 non-null     int64
#  4   period                 58 non-null     object
#  5   TO_Decision_Rural      58 non-null     int64
#  6   TO_RT_Rural            58 non-null     float64
#  7   TO_MaxSWA_Rural        58 non-null     float64
#  8   TO_ReengageTime_Rural  40 non-null     float64
#  9   TO_MaxBraking_Rural    58 non-null     float64
#  10  TO_Decision_Urban      49 non-null     float64
#  11  TO_RT_Urban            49 non-null     float64
#  12  TO_MaxSWA_Urban        49 non-null     float64
#  13  TO_ReengageTime_Urban  39 non-null     float64
#  14  TO_MaxBraking_Urban    49 non-null     float64
# dtypes: float64(9), int64(4), object(2)
# memory usage: 6.9+ KB

# %%
data.head()
# Out:
#    subject_id  label_sleep label_first_scenario  label_time_exp   period  \
# 0           1            0          Countryside              16  Country
# 1           2            1                Urban              16  Country
# 2           3            0          Countryside              16  Country
# 3           4            1          Countryside              16  Country
# 4           5            0          Countryside              10  Country
#
#    TO_Decision_Rural  TO_RT_Rural  TO_MaxSWA_Rural  TO_ReengageTime_Rural  \
# 0                  1        2.450              5.0                 12.399
# 1                  4        2.900              2.0                  3.233
# 2                  1        2.233              7.0                 25.767
# 3                  4        1.665             37.0                    NaN
# 4                  1        1.467              6.0                  3.750
#
#    TO_MaxBraking_Rural  TO_Decision_Urban  TO_RT_Urban  TO_MaxSWA_Urban  \
# 0                100.0                1.0        1.484              1.0
# 1                  0.0                NaN          NaN              NaN
# 2                100.0                1.0        2.918              5.0
# 3                100.0                1.0        1.467             10.0
# 4                100.0                NaN          NaN              NaN
#
#    TO_ReengageTime_Urban  TO_MaxBraking_Urban
# 0                  9.900                100.0
# 1                    NaN                  NaN
# 2                 14.068                 95.2
# 3                    NaN                100.0
# 4                    NaN                  NaN

# %%
label_counts = data["label_sleep"].value_counts()
print(label_counts)
# Out:
# label_sleep
# 1    31
# 0    27
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")
plt.title("Class Distribution: label_sleep")
plt.xlabel("Classes")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\kahch\AppData\Local\Temp\ipykernel_62964\3141730654.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")

# %% [markdown]
# #Data Preprocessing

# %%
columns_to_exclude = data.columns[data.isnull().mean() > 0.5]
data = data.drop(columns=columns_to_exclude)

data.replace([np.inf, -np.inf], np.nan, inplace=True)

numerical_data = data.select_dtypes(include=['number'])

missing_values = numerical_data.isnull().sum()
print("Missing Values:\n", missing_values[missing_values > 0])

data.fillna(numerical_data.mean(), inplace=True)

missing_after = data.isnull().sum()
print("\nMissing Values After Filling:\n", missing_after[missing_after > 0])

if missing_after.sum() == 0:
    print("\nAll missing values have been successfully filled!")
else:
    print("\nThere are still missing values in the dataset.")
# Out:
# Missing Values:
#  TO_ReengageTime_Rural    18
# TO_Decision_Urban         9
# TO_RT_Urban               9
# TO_MaxSWA_Urban           9
# TO_ReengageTime_Urban    19
# TO_MaxBraking_Urban       9
# dtype: int64
#
# Missing Values After Filling:
#  Series([], dtype: int64)
#
# All missing values have been successfully filled!

# %%
data["label_first_scenario"] = data["label_first_scenario"].map({"Countryside": 0, "Urban": 1})
data["period"] = data["period"].map({"Country": 0, "Urban": 1})

print("\n'label_first_scenario' Column After Encoding:\n", data["label_first_scenario"].head())
print("\n'period' Column After Encoding:\n", data["period"].head())
# Out:
# 'label_first_scenario' Column After Encoding:
#  0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: label_first_scenario, dtype: int64
#
# 'period' Column After Encoding:
#  0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: period, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data["label_sleep"] = label_encoder.fit_transform(data["label_sleep"])

print("Encoded Labels:\n", data["label_sleep"].unique())
# Out:
# Encoded Labels:
#  [0 1]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, precision_score, recall_score, f1_score

X = data.drop(columns=['subject_id', 'label_sleep']).values
y = data['label_sleep'].values

encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y.reshape(-1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

print(f"Training Set Size: {x_train.shape}")
print(f"Testing Set Size: {x_test.shape}")

scaler = StandardScaler()
x_train_norm = scaler.fit_transform(x_train)
x_test_norm = scaler.transform(x_test)
# Out:
# Training Set Size: (46, 13)
# Testing Set Size: (12, 13)

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y), y=y)
class_weights_dict = dict(enumerate(class_weights))

input_size = x_train_norm.shape[1]
output_size = y_train.shape[1]

x_train_cnn = x_train_norm.reshape(x_train_norm.shape[0], x_train_norm.shape[1], 1)
x_test_cnn = x_test_norm.reshape(x_test_norm.shape[0], x_test_norm.shape[1], 1)

model = models.Sequential([
    layers.Conv1D(filters=128, kernel_size=3, activation='relu', padding='causal', input_shape=(input_size, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.3),

    layers.Conv1D(filters=64, kernel_size=3, activation='relu', padding='causal'),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.3),

    layers.Flatten(),

    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.4),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.4),
    layers.Dense(output_size, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(
    x_train_cnn, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(x_test_cnn, y_test),
    class_weight=class_weights_dict,
    callbacks=[early_stopping],
    verbose=1
)

val_loss, val_accuracy = model.evaluate(x_test_cnn, y_test, verbose=0)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

y_pred = model.predict(x_test_cnn)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)
# Out:
# Epoch 1/100
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 227ms/step - accuracy: 0.4420 - loss: 3.4306 - val_accuracy: 0.5000 - val_loss: 3.0450
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5041 - loss: 3.3387 - val_accuracy: 0.5000 - val_loss: 3.0239
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5104 - loss: 3.3411 - val_accuracy: 0.4167 - val_loss: 3.0035
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5562 - loss: 3.2425 - val_accuracy: 0.4167 - val_loss: 2.9836
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6037 - loss: 3.1615 - val_accuracy: 0.4167 - val_loss: 2.9640
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6141 - loss: 3.2118 - val_accuracy: 0.4167 - val_loss: 2.9450
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 3.0610 - val_accuracy: 0.5833 - val_loss: 2.9253
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5643 - loss: 3.0157 - val_accuracy: 0.5833 - val_loss: 2.9059
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3673 - loss: 3.0835 - val_accuracy: 0.6667 - val_loss: 2.8874
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5829 - loss: 2.9534 - val_accuracy: 0.6667 - val_loss: 2.8688
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5353 - loss: 2.8852 - val_accuracy: 0.6667 - val_loss: 2.8499
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5145 - loss: 3.0274 - val_accuracy: 0.6667 - val_loss: 2.8311
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6535 - loss: 2.8871 - val_accuracy: 0.6667 - val_loss: 2.8127
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5580 - loss: 2.8300 - val_accuracy: 0.6667 - val_loss: 2.7942
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5145 - loss: 2.9007 - val_accuracy: 0.5833 - val_loss: 2.7757
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6286 - loss: 2.7866 - val_accuracy: 0.5833 - val_loss: 2.7570
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5063 - loss: 2.8177 - val_accuracy: 0.5833 - val_loss: 2.7379
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5684 - loss: 2.8767 - val_accuracy: 0.5833 - val_loss: 2.7189
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7074 - loss: 2.6853 - val_accuracy: 0.5833 - val_loss: 2.7002
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7178 - loss: 2.6534 - val_accuracy: 0.5833 - val_loss: 2.6819
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6703 - loss: 2.6354 - val_accuracy: 0.5000 - val_loss: 2.6641
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5684 - loss: 2.6806 - val_accuracy: 0.5000 - val_loss: 2.6462
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6327 - loss: 2.6612 - val_accuracy: 0.5000 - val_loss: 2.6284
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6929 - loss: 2.6240 - val_accuracy: 0.5000 - val_loss: 2.6102
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7613 - loss: 2.5192 - val_accuracy: 0.5000 - val_loss: 2.5925
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6245 - loss: 2.5729 - val_accuracy: 0.5000 - val_loss: 2.5754
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7074 - loss: 2.5339 - val_accuracy: 0.5000 - val_loss: 2.5583
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7966 - loss: 2.4229 - val_accuracy: 0.5000 - val_loss: 2.5411
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7074 - loss: 2.4591 - val_accuracy: 0.5833 - val_loss: 2.5242
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6576 - loss: 2.4499 - val_accuracy: 0.5833 - val_loss: 2.5074
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7323 - loss: 2.3551 - val_accuracy: 0.5833 - val_loss: 2.4910
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8922 - loss: 2.3390 - val_accuracy: 0.5833 - val_loss: 2.4748
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7572 - loss: 2.3848 - val_accuracy: 0.5833 - val_loss: 2.4583
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7613 - loss: 2.3079 - val_accuracy: 0.5833 - val_loss: 2.4418
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6970 - loss: 2.4521 - val_accuracy: 0.5833 - val_loss: 2.4256
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7283 - loss: 2.2926 - val_accuracy: 0.5833 - val_loss: 2.4092
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7219 - loss: 2.2596 - val_accuracy: 0.5833 - val_loss: 2.3926
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7468 - loss: 2.2928 - val_accuracy: 0.5833 - val_loss: 2.3764
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7219 - loss: 2.2845 - val_accuracy: 0.6667 - val_loss: 2.3603
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7219 - loss: 2.2420 - val_accuracy: 0.6667 - val_loss: 2.3443
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6848 - loss: 2.2106 - val_accuracy: 0.6667 - val_loss: 2.3284
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7822 - loss: 2.1573 - val_accuracy: 0.6667 - val_loss: 2.3126
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7468 - loss: 2.2616 - val_accuracy: 0.6667 - val_loss: 2.2967
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6866 - loss: 2.1866 - val_accuracy: 0.6667 - val_loss: 2.2809
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7572 - loss: 2.1486 - val_accuracy: 0.6667 - val_loss: 2.2650
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8279 - loss: 2.0888 - val_accuracy: 0.6667 - val_loss: 2.2497
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8216 - loss: 2.0704 - val_accuracy: 0.6667 - val_loss: 2.2349
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8030 - loss: 2.1749 - val_accuracy: 0.6667 - val_loss: 2.2203
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7178 - loss: 2.0482 - val_accuracy: 0.6667 - val_loss: 2.2057
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7926 - loss: 2.0317 - val_accuracy: 0.6667 - val_loss: 2.1904
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7822 - loss: 2.0099 - val_accuracy: 0.6667 - val_loss: 2.1752
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8175 - loss: 1.9478 - val_accuracy: 0.6667 - val_loss: 2.1603
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8777 - loss: 1.9020 - val_accuracy: 0.6667 - val_loss: 2.1457
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7966 - loss: 1.9018 - val_accuracy: 0.6667 - val_loss: 2.1316
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8610 - loss: 1.8786 - val_accuracy: 0.6667 - val_loss: 2.1171
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7822 - loss: 1.9075 - val_accuracy: 0.6667 - val_loss: 2.1027
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7781 - loss: 1.8607 - val_accuracy: 0.6667 - val_loss: 2.0886
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8569 - loss: 1.8804 - val_accuracy: 0.6667 - val_loss: 2.0757
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8320 - loss: 1.8002 - val_accuracy: 0.6667 - val_loss: 2.0630
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8610 - loss: 1.7933 - val_accuracy: 0.6667 - val_loss: 2.0498
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7074 - loss: 2.0035 - val_accuracy: 0.7500 - val_loss: 2.0373
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9212 - loss: 1.7221 - val_accuracy: 0.7500 - val_loss: 2.0250
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8505 - loss: 1.7727 - val_accuracy: 0.7500 - val_loss: 2.0126
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8465 - loss: 1.7808 - val_accuracy: 0.7500 - val_loss: 2.0001
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8528 - loss: 1.7143 - val_accuracy: 0.7500 - val_loss: 1.9879
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8465 - loss: 1.7112 - val_accuracy: 0.7500 - val_loss: 1.9759
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8424 - loss: 1.7407 - val_accuracy: 0.7500 - val_loss: 1.9641
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7677 - loss: 1.6863 - val_accuracy: 0.7500 - val_loss: 1.9521
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9212 - loss: 1.5903 - val_accuracy: 0.7500 - val_loss: 1.9397
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8465 - loss: 1.7036 - val_accuracy: 0.7500 - val_loss: 1.9278
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8465 - loss: 1.6439 - val_accuracy: 0.7500 - val_loss: 1.9154
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9004 - loss: 1.5504 - val_accuracy: 0.7500 - val_loss: 1.9032
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8610 - loss: 1.5456 - val_accuracy: 0.7500 - val_loss: 1.8905
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9212 - loss: 1.4809 - val_accuracy: 0.7500 - val_loss: 1.8782
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8175 - loss: 1.6192 - val_accuracy: 0.7500 - val_loss: 1.8653
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8859 - loss: 1.5591 - val_accuracy: 0.7500 - val_loss: 1.8520
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9357 - loss: 1.4587 - val_accuracy: 0.7500 - val_loss: 1.8385
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9212 - loss: 1.4807 - val_accuracy: 0.7500 - val_loss: 1.8265
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8963 - loss: 1.5159 - val_accuracy: 0.7500 - val_loss: 1.8152
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9004 - loss: 1.4635 - val_accuracy: 0.7500 - val_loss: 1.8039
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9108 - loss: 1.4984 - val_accuracy: 0.7500 - val_loss: 1.7927
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8505 - loss: 1.4806 - val_accuracy: 0.7500 - val_loss: 1.7817
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8963 - loss: 1.4497 - val_accuracy: 0.7500 - val_loss: 1.7705
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8963 - loss: 1.3613 - val_accuracy: 0.7500 - val_loss: 1.7599
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9253 - loss: 1.3797 - val_accuracy: 0.7500 - val_loss: 1.7489
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8963 - loss: 1.3577 - val_accuracy: 0.7500 - val_loss: 1.7367
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9357 - loss: 1.3620 - val_accuracy: 0.7500 - val_loss: 1.7245
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8859 - loss: 1.4371 - val_accuracy: 0.7500 - val_loss: 1.7129
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7613 - loss: 1.5402 - val_accuracy: 0.7500 - val_loss: 1.7005
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9357 - loss: 1.2638 - val_accuracy: 0.7500 - val_loss: 1.6891
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9067 - loss: 1.3621 - val_accuracy: 0.7500 - val_loss: 1.6791
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8714 - loss: 1.3605 - val_accuracy: 0.7500 - val_loss: 1.6692
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9212 - loss: 1.2870 - val_accuracy: 0.7500 - val_loss: 1.6606
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8859 - loss: 1.3154 - val_accuracy: 0.7500 - val_loss: 1.6517
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8714 - loss: 1.2681 - val_accuracy: 0.7500 - val_loss: 1.6427
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9253 - loss: 1.2770 - val_accuracy: 0.7500 - val_loss: 1.6340
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8505 - loss: 1.3388 - val_accuracy: 0.7500 - val_loss: 1.6254
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9461 - loss: 1.1747 - val_accuracy: 0.7500 - val_loss: 1.6169
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9357 - loss: 1.1662 - val_accuracy: 0.7500 - val_loss: 1.6080
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8505 - loss: 1.3195 - val_accuracy: 0.7500 - val_loss: 1.5986
# Validation Accuracy: 75.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step

# %%
print("Classification Report:\n")
print(classification_report(y_true_classes, y_pred_classes))

accuracy = accuracy_score(y_true_classes, y_pred_classes)
if y_test.shape[1] == 2:
    roc_auc = roc_auc_score(y_true_classes, y_pred[:, 1])
else:
    roc_auc = roc_auc_score(y_test, y_pred, multi_class='ovr', average='weighted')

precision = precision_score(y_true_classes, y_pred_classes, average='macro')
recall = recall_score(y_true_classes, y_pred_classes, average='macro')
f1 = f1_score(y_true_classes, y_pred_classes, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         6
#            1       1.00      0.50      0.67         6
#
#     accuracy                           0.75        12
#    macro avg       0.83      0.75      0.73        12
# weighted avg       0.83      0.75      0.73        12
#
# Accuracy: 0.75
# ROC-AUC Score: 0.83
# Precision: 0.83
# Recall: 0.75
# F1-Score: 0.73

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(10, 8))
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc, average_precision_score

plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, 
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves Graph')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred[:, i])
    avg_precision = average_precision_score(y_test[:, i], y_pred[:, i])
    plt.plot(recall, precision, lw=2,
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AP = {avg_precision:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\kahch\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (2.1.0)
# Requirement already satisfied: numpy in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (13.7.1)
# Requirement already satisfied: namex in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kahch\anaconda3\lib\site-packages (from optree->keras->keras-tuner) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kahch\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kahch\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kahch\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)

# %%
import keras_tuner as kt

def build_causal_cnn_model(hp):
    input_size = x_train_cnn.shape[1]
    output_size = y_train.shape[1]

    model = models.Sequential()

    model.add(layers.Conv1D(
        filters=hp.Choice('filters_1', values=[32, 64, 128]),
        kernel_size=hp.Choice('kernel_size_1', values=[3, 5]),
        activation='relu',
        padding='causal',
        input_shape=(input_size, 1)
    ))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling1D(pool_size=2))
    model.add(layers.Dropout(hp.Choice('dropout_1', values=[0.2, 0.3, 0.4])))

    model.add(layers.Conv1D(
        filters=hp.Choice('filters_2', values=[32, 64]),
        kernel_size=hp.Choice('kernel_size_2', values=[3, 5]),
        activation='relu',
        padding='causal'
    ))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling1D(pool_size=2))
    model.add(layers.Dropout(hp.Choice('dropout_2', values=[0.2, 0.3, 0.4])))

    model.add(layers.Flatten())

    model.add(layers.Dense(
        units=hp.Choice('units_1', values=[64, 128]),
        activation='relu',
        kernel_regularizer=regularizers.l2(0.01)
    ))
    model.add(layers.Dropout(hp.Choice('dropout_3', values=[0.3, 0.4])))

    model.add(layers.Dense(
        units=hp.Choice('units_2', values=[32, 64]),
        activation='relu',
        kernel_regularizer=regularizers.l2(0.01)
    ))
    model.add(layers.Dropout(hp.Choice('dropout_4', values=[0.3, 0.4])))

    model.add(layers.Dense(output_size, activation='sigmoid'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Choice('learning_rate', values=[0.001, 0.005, 0.01])
        ),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

tuner = kt.Hyperband(
    build_causal_cnn_model,
    objective='val_accuracy',
    max_epochs=50,
    factor=3,
    directory='Causual_CNN_Tuning',
    project_name='Causual_CNN_Hyperparameter_Tuning'
)

hyper_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

tuner.search(
    x_train_cnn, y_train,
    validation_data=(x_test_cnn, y_test),
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[hyper_early_stopping],
    verbose=1
)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:")
print(f"Filters in Layer 1: {best_hps.get('filters_1')}")
print(f"Kernel Size in Layer 1: {best_hps.get('kernel_size_1')}")
print(f"Dropout in Layer 1: {best_hps.get('dropout_1')}")
print(f"Filters in Layer 2: {best_hps.get('filters_2')}")
print(f"Kernel Size in Layer 2: {best_hps.get('kernel_size_2')}")
print(f"Dropout in Layer 2: {best_hps.get('dropout_2')}")
print(f"Units in Dense Layer 1: {best_hps.get('units_1')}")
print(f"Dropout in Dense Layer 1: {best_hps.get('dropout_3')}")
print(f"Units in Dense Layer 2: {best_hps.get('units_2')}")
print(f"Dropout in Dense Layer 2: {best_hps.get('dropout_4')}")
print(f"Learning Rate: {best_hps.get('learning_rate')}")

best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(
    x_train_cnn, y_train,
    validation_data=(x_test_cnn, y_test),
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[hyper_early_stopping],
    verbose=1
)

y_pred_best = best_model.predict(x_test_cnn)
y_pred_best_classes = np.argmax(y_pred_best, axis=1)
y_true_best_classes = np.argmax(y_test, axis=1)
# Out:
# Trial 90 Complete [00h 00m 08s]
# val_accuracy: 0.75
#
# Best val_accuracy So Far: 0.9166666865348816
# Total elapsed time: 00h 06m 03s
# Best Hyperparameters:
# Filters in Layer 1: 32
# Kernel Size in Layer 1: 3
# Dropout in Layer 1: 0.4
# Filters in Layer 2: 64
# Kernel Size in Layer 2: 5
# Dropout in Layer 2: 0.2
# Units in Dense Layer 1: 128
# Dropout in Dense Layer 1: 0.3
# Units in Dense Layer 2: 32
# Dropout in Dense Layer 2: 0.3
# Learning Rate: 0.01
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.5539 - loss: 3.0884 - val_accuracy: 0.4167 - val_loss: 2.6155
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4896 - loss: 3.0297 - val_accuracy: 0.5000 - val_loss: 2.4981
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5788 - loss: 2.6339 - val_accuracy: 0.5000 - val_loss: 2.3876
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5539 - loss: 2.4856 - val_accuracy: 0.5000 - val_loss: 2.2788
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6078 - loss: 2.2141 - val_accuracy: 0.5833 - val_loss: 2.1723
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7966 - loss: 2.0421 - val_accuracy: 0.5000 - val_loss: 2.0710
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6431 - loss: 1.9031 - val_accuracy: 0.5000 - val_loss: 1.9703
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6784 - loss: 1.8360 - val_accuracy: 0.5000 - val_loss: 1.8733
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6599 - loss: 1.8168 - val_accuracy: 0.4167 - val_loss: 1.7860
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8424 - loss: 1.5382 - val_accuracy: 0.4167 - val_loss: 1.7046
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7034 - loss: 1.5773 - val_accuracy: 0.5000 - val_loss: 1.6224
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7074 - loss: 1.4706 - val_accuracy: 0.5000 - val_loss: 1.5504
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7364 - loss: 1.4466 - val_accuracy: 0.4167 - val_loss: 1.4897
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7428 - loss: 1.3711 - val_accuracy: 0.4167 - val_loss: 1.4277
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7677 - loss: 1.2648 - val_accuracy: 0.5000 - val_loss: 1.3678
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7572 - loss: 1.1762 - val_accuracy: 0.5000 - val_loss: 1.3168
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8175 - loss: 1.1125 - val_accuracy: 0.4167 - val_loss: 1.2745
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7966 - loss: 1.0477 - val_accuracy: 0.5000 - val_loss: 1.2386
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7219 - loss: 1.0634 - val_accuracy: 0.5000 - val_loss: 1.2061
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8071 - loss: 0.9655 - val_accuracy: 0.5000 - val_loss: 1.1774
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8216 - loss: 0.9222 - val_accuracy: 0.5000 - val_loss: 1.1480
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8424 - loss: 0.8208 - val_accuracy: 0.5000 - val_loss: 1.1176
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8569 - loss: 0.8667 - val_accuracy: 0.5833 - val_loss: 1.0875
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9108 - loss: 0.7265 - val_accuracy: 0.5000 - val_loss: 1.0667
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8216 - loss: 0.8774 - val_accuracy: 0.5833 - val_loss: 1.0310
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8465 - loss: 0.7910 - val_accuracy: 0.6667 - val_loss: 1.0081
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8465 - loss: 0.6599 - val_accuracy: 0.6667 - val_loss: 0.9905
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7428 - loss: 0.7286 - val_accuracy: 0.6667 - val_loss: 0.9721
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8818 - loss: 0.6078 - val_accuracy: 0.5000 - val_loss: 0.9729
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9502 - loss: 0.5625 - val_accuracy: 0.5000 - val_loss: 1.0085
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8673 - loss: 0.6346 - val_accuracy: 0.5000 - val_loss: 1.0106
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9461 - loss: 0.5461 - val_accuracy: 0.5833 - val_loss: 0.9551
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8818 - loss: 0.5995 - val_accuracy: 0.7500 - val_loss: 0.9402
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8963 - loss: 0.6008 - val_accuracy: 0.6667 - val_loss: 0.9589
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9710 - loss: 0.5373 - val_accuracy: 0.6667 - val_loss: 0.9977
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8610 - loss: 0.6275 - val_accuracy: 0.5000 - val_loss: 1.0392
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9751 - loss: 0.4579 - val_accuracy: 0.5000 - val_loss: 1.0577
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9212 - loss: 0.6369 - val_accuracy: 0.4167 - val_loss: 1.0520
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8714 - loss: 0.5634 - val_accuracy: 0.5000 - val_loss: 1.0677
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8361 - loss: 0.6942 - val_accuracy: 0.5000 - val_loss: 1.0274
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9212 - loss: 0.5491 - val_accuracy: 0.5000 - val_loss: 0.9697
# Epoch 42/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8569 - loss: 0.5937 - val_accuracy: 0.5833 - val_loss: 0.9444
# Epoch 43/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8963 - loss: 0.5699 - val_accuracy: 0.5833 - val_loss: 0.9393
# Epoch 44/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8818 - loss: 0.5342 - val_accuracy: 0.5833 - val_loss: 0.9643
# Epoch 45/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9108 - loss: 0.5485 - val_accuracy: 0.5833 - val_loss: 0.9651
# Epoch 46/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9357 - loss: 0.5148 - val_accuracy: 0.5833 - val_loss: 0.9521
# Epoch 47/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8111 - loss: 0.5772 - val_accuracy: 0.5000 - val_loss: 0.9293
# Epoch 48/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9212 - loss: 0.5428 - val_accuracy: 0.6667 - val_loss: 0.8930
# Epoch 49/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9212 - loss: 0.4813 - val_accuracy: 0.6667 - val_loss: 0.8644
# Epoch 50/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8818 - loss: 0.5268 - val_accuracy: 0.7500 - val_loss: 0.8583
# Epoch 51/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9004 - loss: 0.5537 - val_accuracy: 0.5833 - val_loss: 0.8823
# Epoch 52/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8963 - loss: 0.4642 - val_accuracy: 0.5833 - val_loss: 0.9074
# Epoch 53/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9710 - loss: 0.4148 - val_accuracy: 0.5833 - val_loss: 0.9024
# Epoch 54/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9751 - loss: 0.3871 - val_accuracy: 0.5833 - val_loss: 0.8744
# Epoch 55/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9067 - loss: 0.5682 - val_accuracy: 0.6667 - val_loss: 0.8758
# Epoch 56/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8818 - loss: 0.5433 - val_accuracy: 0.5833 - val_loss: 0.9233
# Epoch 57/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9108 - loss: 0.5314 - val_accuracy: 0.5833 - val_loss: 0.9938
# Epoch 58/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9108 - loss: 0.4945 - val_accuracy: 0.4167 - val_loss: 1.0616
# Epoch 59/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9855 - loss: 0.4365 - val_accuracy: 0.4167 - val_loss: 1.1063
# Epoch 60/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9502 - loss: 0.4707 - val_accuracy: 0.4167 - val_loss: 1.1268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step

# %%
print("Classification Report:")
print(classification_report(y_true_best_classes, y_pred_best_classes))

accuracy = accuracy_score(y_true_best_classes, y_pred_best_classes)
roc_auc = roc_auc_score(y_test, y_pred_best, multi_class='ovr', average='weighted')
precision = precision_score(y_true_best_classes, y_pred_best_classes, average='macro')
recall = recall_score(y_true_best_classes, y_pred_best_classes, average='macro')
f1 = f1_score(y_true_best_classes, y_pred_best_classes, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         6
#            1       0.67      1.00      0.80         6
#
#     accuracy                           0.75        12
#    macro avg       0.83      0.75      0.73        12
# weighted avg       0.83      0.75      0.73        12
#
# Accuracy: 0.75
# ROC-AUC Score: 0.92
# Precision: 0.83
# Recall: 0.75
# F1-Score: 0.73

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true_best_classes, y_pred_best_classes)

plt.figure(figsize=(10, 8))
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_best[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, 
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves Graph')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred_best[:, i])
    avg_precision = average_precision_score(y_test[:, i], y_pred_best[:, i])
    plt.plot(recall, precision, lw=2,
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AP = {avg_precision:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 13, 128)        │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 13, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 6, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 6, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 6, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 3, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 3, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 192)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 176,264 (688.54 KB)
#  Trainable params: 58,626 (229.01 KB)
#  Non-trainable params: 384 (1.50 KB)
#  Optimizer params: 117,254 (458.03 KB)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 13, 32)         │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 13, 32)         │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 6, 64)          │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 6, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 3, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 3, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 192)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,760 (463.91 KB)
#  Trainable params: 39,522 (154.38 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 79,046 (308.78 KB)

# %%
import shap

subset_data = x_test_cnn

explainer = shap.DeepExplainer(model, subset_data)

shap_values = explainer.shap_values(subset_data)
# Out:
# c:\Users\kahch\anaconda3\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(12, 13, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(24, 13, 1))']
#   warnings.warn(msg)

# %%
feature_names = data.drop(columns=['subject_id', 'label_sleep']).columns.tolist()
expected_value = explainer.expected_value[0].numpy()

shap.plots.waterfall(
    shap.Explanation(
        values=shap_values[0, :, 0, 0],
        base_values=expected_value,
        data=subset_data[0].flatten(),
        feature_names=feature_names
    ),
)
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.

# %%
shap.initjs()
subset_data_reshaped = subset_data.reshape(subset_data.shape[0], subset_data.shape[1])

shap.plots.force(
    expected_value,
    shap_values[:, :, 0, 0],
    subset_data_reshaped,
    feature_names=feature_names
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iY8MLA87FCXEKRXYYSAFP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5620619058609009, "link": "identity", "featureNames": ["label_first_scenario", "label_time_exp", "period", "TO_Decision_Rural", "TO_RT_Rural", "TO_MaxSWA_Rural", "TO_ReengageTime_Rural", "TO_MaxBraking_Rural", "TO_Decision_Urban", "TO_RT_Urban", "TO_MaxSWA_Urban", "TO_ReengageTime_Urban", "TO_MaxBraking_Urban"], "explanations": [{"outValue": 0.6260230551369418, "simIndex": 3.0, "features": {"0": {"effect": -0.008411286981138723, "value": -1.0910894511799616}, "1": {"effect": 0.005262692802476728, "value": 0.8017837257372732}, "2": {"effect": 0.0, "value": 0.0}, "3": {"effect": 0.013753071008063673, "value": -1.0220970289135212}, "4": {"effect": 0.0016031085610442974, "value": -0.20307782007206088}, "5": {"effect": 0.015945049721946405, "value": -0.49233288302173084}, "6": {"effect": 0.032202264292230526, "value": -0.24597804614743163}, "7": {"effect": 0.005830628342041196, "value": 0.3106119091159555}, "8": {"effect": -0.006335632897770712, "value": -1.1530401452384142}, "9": {"effect": -0.010766903824222913, "value": -0.7645429418203944}, "10": {"effect": 0.004830784067317317, "value": -0.49721785083070136}, "11": {"effect": 0.01004737418405308, "value": -0.6872201742960512}, "12": {"effect": 0.0, "value": 0.485757619860025}}}, {"outValue": 0.6279276401226618, "simIndex": 4.0, "features": {"0": {"effect": -0.004707720968974691, "value": 0.9165151389911678}, "1": {"effect": -0.006784725021329194, "value": 0.8017837257372732}, "2": {"effect": 0.0, "value": 0.0}, "3": {"effect": -0.005816435625585707, "value": 1.0831177470576123}, "4": {"effect": -0.006833393002488894, "value": -0.7806833596379456}, "5": {"effect": 0.011909627812526302, "value": -0.41333062969963913}, "6": {"effect": 0.02007365529044895, "value": -0.10961309179772737}, "7": {"effect": 0.005102232931330736, "value": 0.3106119091159555}, "8": {"effect": -0.00024117821789877703, "value": -1.1530401452384142}, "9": {"effect": 0.027352692066541204, "value": 0.6383517053384838}, "10": {"effect": 0.012067188994653762, "value": -0.1337872757930359}, "11": {"effect": 0.013743790002537252, "value": 0.2246327872696081}, "12": {"effect": 0.0, "value": 0.485757619860025}}}, {"outValue": 0.4727080481141396, "simIndex": 9.0, "features": {"0": {"effect": -0.02178003529931626, "value": -1.0910894511799616}, "1": {"effect": -0.021756159887237902, "value": -1.2472191289246475}, "2": {"effect": 0.0, "value": 0.0}, "3": {"effect": 0.008411434368379355, "value": 1.0831177470576123}, "4": {"effect": 0.0008410189318049047, "value": -0.21306692909812391}, "5": {"effect": -0.02395509614948625, "value": 0.35035781908058056}, "6": {"effect": -0.010912089048787002, "value": 0.07240291197027945}, "7": {"effect": -0.0033920270016731115, "value": 0.3106119091159555}, "8": {"effect": -0.009450134813921969, "value": 1.1220860473796646}, "9": {"effect": -0.02740574479494169, "value": -0.7344458149767933}, "10": {"effect": 0.005685747727680699, "value": -0.45178902895099315}, "11": {"effect": 0.014359228220737897, "value": 0.11609595148810511}, "12": {"effect": 0.0, "value": 0.485757619860025}}}, {"outValue": 0.6991123029895367, "simIndex": 12.0, "features": {"0": {"effect": 0.013983539018654097, "value": 0.9165151389911678}, "1": {"effect": 0.006211410367758483, "value": -1.2472191289246475}, "2": {"effect": 0.0, "value": 0.0}, "3": {"effect": -0.012473808552528188, "value": -1.0220970289135212}, "4": {"effect": 0.02244513442688349, "value": 2.1572898833217935}, "5": {"effect": 0.0014446173737614274, "value": -0.5713351363438225}, "6": {"effect": 0.0027831834977599217, "value": 0.07240291197027945}, "7": {"effect": 0.009954344679877391, "value": 0.3106119091159555}, "8": {"effect": 0.047304408008489084, "value": -0.023215573394062137}, "9": {"effect": 0.022481335147480602, "value": -0.07801256157451866}, "10": {"effect": 0.013998742115236308, "value": 0.013624615612547786}, "11": {"effect": 0.008 ...

# %%
shap.summary_plot(
    shap_values[:, :, 0, 0],
    subset_data_reshaped,
    feature_names=feature_names
)

# %%
shap_exp = shap.Explanation(
    values=shap_values[:, :, 0, 0],
    base_values=expected_value,
    data=subset_data_reshaped,
    feature_names=feature_names
)

shap.plots.beeswarm(shap_exp)

# %%
shap.plots.bar(
    shap.Explanation(
        values=shap_values[0, :, 0, 0],
        base_values=expected_value,
        data=subset_data[0].flatten(),
        feature_names=feature_names
    )
)

# %%
pip install quantus
# Out:
# Requirement already satisfied: quantus in c:\users\kahch\anaconda3\lib\site-packages (0.5.3)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.26.4)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (2.2.2)
# Requirement already satisfied: opencv-python>=4.5.5.62 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (4.11.0.86)
# Requirement already satisfied: scikit-image>=0.19.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (0.24.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.5.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.13.1)
# Requirement already satisfied: tqdm>=4.62.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (4.66.5)
# Requirement already satisfied: matplotlib>=3.3.4 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kahch\anaconda3\lib\site-packages (from pandas>=1.5.3->quantus) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kahch\anaconda3\lib\site-packages (from pandas>=1.5.3->quantus) (2023.3)
# Requirement already satisfied: networkx>=2.8 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (3.3)
# Requirement already satisfied: imageio>=2.33 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->quantus) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->quantus) (3.5.0)
# Requirement already satisfied: colorama in c:\users\kahch\anaconda3\lib\site-packages (from tqdm>=4.62.3->quantus) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kahch\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->quantus) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)

# %%
import quantus

def shap_explain_func(model, inputs, targets, **kwargs):

    if inputs.ndim == 3 and inputs.shape[1] == 1:
        inputs_reshaped = np.transpose(inputs, (0, 2, 1))
    else:
        inputs_reshaped = inputs

    background = inputs_reshaped[:100]

    explainer = shap.DeepExplainer(model, background)

    shap_values = explainer.shap_values(inputs_reshaped)

    explanations = shap_values[:, :, 0, 0]
    
    return explanations

def evaluate_xai_metrics(x_batch: np.ndarray, y_batch: np.ndarray, 
                        attributions: np.ndarray, n_samples):
    
    x_batch = x_batch[:n_samples]
    y_batch = y_batch[:n_samples]
    attributions = attributions[:n_samples]

    metrics = {
        "robustness": quantus.AvgSensitivity(
            nr_samples=2,
            lower_bound=0.2,
            norm_numerator=quantus.norm_func.fro_norm,
            norm_denominator=quantus.norm_func.fro_norm,
            perturb_func=quantus.perturb_func.uniform_noise,
            similarity_func=quantus.similarity_func.difference,
            abs=True,
            normalise=False,
            aggregate_func=np.mean,
            return_aggregate=True,
            disable_warnings=True,
            display_progressbar=True,
        ),
        "complexity": quantus.Sparseness(
            abs=True,
            normalise=True,
            disable_warnings=True,
            display_progressbar=True,
            return_aggregate=True,
        ),
        "randomisation": quantus.MPRT(
            similarity_func=quantus.similarity_func.correlation_spearman,
            return_average_correlation=True,
            aggregate_func=np.mean,
            layer_order="independent",
            disable_warnings=True,
            normalise=True,
            abs=True,
            display_progressbar=True,
        )
    }

    results = {}
    for metric_name, metric in metrics.items():
        score = metric(
            model=model,
            x_batch=x_batch,
            y_batch=y_batch,
            a_batch=attributions,
            explain_func=shap_explain_func
        )
        score_value = np.mean(score) if isinstance(score, (np.ndarray, list)) else score
            
        results[metric_name] = score_value
        print(f"{metric_name.capitalize()} Score: {score_value:.4f}")
    
    return results

def plot_metric_results(results):
    results = {k: v for k, v in results.items() if v is not None}
        
    plt.figure(figsize=(10, 6))
    metrics = list(results.keys())
    scores = list(results.values())
    
    bars = plt.bar(metrics, scores)
    plt.title('XAI Evaluation Metrics')
    plt.xticks(rotation=45)
    plt.ylabel('Score')
    
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.4f}',
                ha='center', va='bottom')
    
    plt.tight_layout()
    plt.show()


y_test_classes = np.argmax(y_test, axis=1)

results = evaluate_xai_metrics(
    x_batch=x_test_cnn,
    y_batch=y_test_classes,
    attributions=shap_values[:, :, 0, 0],
    n_samples=100
)

plot_metric_results(results)
# Out:
#   0%|          | 0/1.0 [00:00<?, ?it/s]
# c:\Users\kahch\anaconda3\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(12, 13, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(24, 13, 1))']
#   warnings.warn(msg)
# Robustness Score: 0.3540
#   0%|          | 0/1.0 [00:00<?, ?it/s]
# Complexity Score: 0.5083
#   0%|          | 0/84 [00:00<?, ?it/s]
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer
# Received: inputs=['Tensor(shape=(12, 13, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer
# Received: inputs=['Tensor(shape=(24, 13, 1))']
#   warnings.warn(msg)
# Randomisation Score: 0.6858
