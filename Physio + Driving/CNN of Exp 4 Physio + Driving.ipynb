# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# physio_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/Physio/periods/features_segm_1.csv"
# driving_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/Driving/features_tor_10s_30s_rows.csv"
# pvt_path = "/content/drive/MyDrive/Colab Notebooks/FYP/data/Exp4/Exp4/Preprocessed/PVT/data_PVT_no_outliers_mean_sd.csv"

# %%
physio_path = "../Exp4/Preprocessed/Physio/periods/features_segm_1.csv"
driving_path = "../Exp4/Preprocessed/Driving/features_tor_10s_30s_rows.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

physio_data = pd.read_csv(physio_path)
driving_data = pd.read_csv(driving_path)

# Drop specified columns from driving_data
columns_to_drop = ['label_sleep', 'label_first_scenario', 'label_time_exp', 'period']
driving_data = driving_data.drop(columns=columns_to_drop)

data = pd.merge(physio_data, driving_data, on='subject_id', how='inner')

print(data.head())
# Out:
#    subject_id  label_sleep label_first_scenario  label_time_exp period  \
# 0           1            0                Rural              16  Rural
# 1           1            0                Rural              16  Urban
# 2           2            1                Urban              16  Urban
# 3           2            1                Urban              16  Rural
# 4           3            0                Rural              16  Rural
#
#    segment_id  EDA_filtered_mean_Bl  EDA_filtered_min_Bl  EDA_filtered_max_Bl  \
# 0           0              2.188997             1.648550             3.448137
# 1           0              2.188997             1.648550             3.448137
# 2           0             11.196484             9.901155            14.980536
# 3           0             11.196484             9.901155            14.980536
# 4           0             14.989715            10.716242            23.833487
#
#    EDA_filtered_std_Bl  ...  TO_Decision_Rural  TO_RT_Rural  TO_MaxSWA_Rural  \
# 0             0.401299  ...                  1        2.450              5.0
# 1             0.401299  ...                  1        2.450              5.0
# 2             1.039038  ...                  4        2.900              2.0
# 3             1.039038  ...                  4        2.900              2.0
# 4             2.427384  ...                  1        2.233              7.0
#
#    TO_ReengageTime_Rural  TO_MaxBraking_Rural  TO_Decision_Urban  TO_RT_Urban  \
# 0                 12.399                100.0                1.0        1.484
# 1                 12.399                100.0                1.0        1.484
# 2                  3.233                  0.0                NaN          NaN
# 3                  3.233                  0.0                NaN          NaN
# 4                 25.767                100.0                1.0        2.918
#
#    TO_MaxSWA_Urban  TO_ReengageTime_Urban  TO_MaxBraking_Urban
# 0              1.0                  9.900                100.0
# 1              1.0                  9.900                100.0
# 2              NaN                    NaN                  NaN
# 3              NaN                    NaN                  NaN
# 4              5.0                 14.068                 95.2
#
# [5 rows x 412 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Columns: 412 entries, subject_id to TO_MaxBraking_Urban
# dtypes: float64(405), int64(5), object(2)
# memory usage: 373.5+ KB

# %%
data.head()
# Out:
#    subject_id  label_sleep label_first_scenario  label_time_exp period  \
# 0           1            0                Rural              16  Rural
# 1           1            0                Rural              16  Urban
# 2           2            1                Urban              16  Urban
# 3           2            1                Urban              16  Rural
# 4           3            0                Rural              16  Rural
#
#    segment_id  EDA_filtered_mean_Bl  EDA_filtered_min_Bl  EDA_filtered_max_Bl  \
# 0           0              2.188997             1.648550             3.448137
# 1           0              2.188997             1.648550             3.448137
# 2           0             11.196484             9.901155            14.980536
# 3           0             11.196484             9.901155            14.980536
# 4           0             14.989715            10.716242            23.833487
#
#    EDA_filtered_std_Bl  ...  TO_Decision_Rural  TO_RT_Rural  TO_MaxSWA_Rural  \
# 0             0.401299  ...                  1        2.450              5.0
# 1             0.401299  ...                  1        2.450              5.0
# 2             1.039038  ...                  4        2.900              2.0
# 3             1.039038  ...                  4        2.900              2.0
# 4             2.427384  ...                  1        2.233              7.0
#
#    TO_ReengageTime_Rural  TO_MaxBraking_Rural  TO_Decision_Urban  TO_RT_Urban  \
# 0                 12.399                100.0                1.0        1.484
# 1                 12.399                100.0                1.0        1.484
# 2                  3.233                  0.0                NaN          NaN
# 3                  3.233                  0.0                NaN          NaN
# 4                 25.767                100.0                1.0        2.918
#
#    TO_MaxSWA_Urban  TO_ReengageTime_Urban  TO_MaxBraking_Urban
# 0              1.0                  9.900                100.0
# 1              1.0                  9.900                100.0
# 2              NaN                    NaN                  NaN
# 3              NaN                    NaN                  NaN
# 4              5.0                 14.068                 95.2
#
# [5 rows x 412 columns]

# %%
label_counts = data["label_sleep"].value_counts()
print(label_counts)
# Out:
# label_sleep
# 1    62
# 0    54
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")
plt.title("Class Distribution: label_sleep")
plt.xlabel("Classes")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\kahch\AppData\Local\Temp\ipykernel_8892\3141730654.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette="viridis")

# %% [markdown]
# #Data Preprocessing

# %%
columns_to_exclude = data.columns[data.isnull().mean() > 0.5]
data = data.drop(columns=columns_to_exclude)

data.replace([np.inf, -np.inf], np.nan, inplace=True)

numerical_data = data.select_dtypes(include=['number'])

missing_values = numerical_data.isnull().sum()
print("Missing Values:\n", missing_values[missing_values > 0])

data.fillna(numerical_data.mean(), inplace=True)

missing_after = data.isnull().sum()
print("\nMissing Values After Filling:\n", missing_after[missing_after > 0])

if missing_after.sum() == 0:
    print("\nAll missing values have been successfully filled!")
else:
    print("\nThere are still missing values in the dataset.")
# Out:
# Missing Values:
#  HRV_SDANN2_Bl                    44
# HRV_SDNNI2_Bl                    44
# RRV_SampEn_Bl                     2
# HRV_SDANN2_Dr                     1
# HRV_SDNNI2_Dr                     1
# HRV_SDANN5_Dr                     4
# HRV_SDNNI5_Dr                     4
# HRV_VLF_Dr                        9
# HRV_DFA_alpha1_ExpRange_Dr        3
# HRV_DFA_alpha1_ExpMean_Dr         3
# HRV_DFA_alpha1_DimRange_Dr        3
# HRV_DFA_alpha1_DimMean_Dr         3
# RRV_SampEn_Dr                     1
# HRV_DFA_alpha1_DimMean_Dr-Bl      3
# HRV_DFA_alpha1_DimRange_Dr-Bl     3
# HRV_DFA_alpha1_ExpMean_Dr-Bl      3
# HRV_DFA_alpha1_ExpRange_Dr-Bl     3
# HRV_SDANN2_Dr-Bl                 45
# HRV_SDNNI2_Dr-Bl                 45
# RRV_DFA_alpha1_Dr-Bl              2
# RRV_DFA_alpha1_DimMean_Dr-Bl      2
# RRV_DFA_alpha1_DimRange_Dr-Bl     2
# RRV_DFA_alpha1_ExpMean_Dr-Bl      2
# RRV_DFA_alpha1_ExpRange_Dr-Bl     2
# RRV_SampEn_Dr-Bl                  3
# RRV_DFA_alpha1_Bl                 2
# RRV_DFA_alpha1_ExpRange_Bl        2
# RRV_DFA_alpha1_ExpMean_Bl         2
# RRV_DFA_alpha1_DimRange_Bl        2
# RRV_DFA_alpha1_DimMean_Bl         2
# TO_ReengageTime_Rural            36
# TO_Decision_Urban                18
# TO_RT_Urban                      18
# TO_MaxSWA_Urban                  18
# TO_ReengageTime_Urban            38
# TO_MaxBraking_Urban              18
# dtype: int64
#
# Missing Values After Filling:
#  Series([], dtype: int64)
#
# All missing values have been successfully filled!

# %%
data["label_first_scenario"] = data["label_first_scenario"].map({"Rural": 0, "Urban": 1})
data["period"] = data["period"].map({"Rural": 0, "Urban": 1})

print("\n'period' Column After Encoding:\n", data["label_first_scenario"].head())
print("\n'period' Column After Encoding:\n", data["period"].head())
# Out:
# 'period' Column After Encoding:
#  0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: label_first_scenario, dtype: int64
#
# 'period' Column After Encoding:
#  0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: period, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data["label_sleep"] = label_encoder.fit_transform(data["label_sleep"])

print("Encoded Labels:\n", data["label_sleep"].unique())
# Out:
# Encoded Labels:
#  [0 1]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score, precision_score, recall_score, f1_score

X = data.drop(columns=['subject_id', 'label_sleep']).values
y = data['label_sleep'].values

encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y.reshape(-1, 1))

x_train, x_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

print(f"Training Set Size: {x_train.shape}")
print(f"Testing Set Size: {x_test.shape}")

scaler = StandardScaler()
x_train_norm = scaler.fit_transform(x_train)
x_test_norm = scaler.transform(x_test)
# Out:
# Training Set Size: (92, 392)
# Testing Set Size: (24, 392)

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y), y=y)
class_weights_dict = dict(enumerate(class_weights))

input_size = x_train_norm.shape[1]
output_size = y_train.shape[1]

x_train_cnn = x_train_norm.reshape(x_train_norm.shape[0], x_train_norm.shape[1], 1)
x_test_cnn = x_test_norm.reshape(x_test_norm.shape[0], x_test_norm.shape[1], 1)

model = models.Sequential([
    layers.Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(input_size, 1)),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.3),

    layers.Conv1D(filters=64, kernel_size=3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.3),

    layers.Flatten(),

    layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.4),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.4),
    layers.Dense(output_size, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    x_train_cnn, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(x_test_cnn, y_test),
    class_weight=class_weights_dict,
    callbacks=[early_stopping],
    verbose=1
)

val_loss, val_accuracy = model.evaluate(x_test_cnn, y_test, verbose=0)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

y_pred = model.predict(x_test_cnn)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)
# Out:
# Epoch 1/100
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.5389 - loss: 4.4622 - val_accuracy: 0.5417 - val_loss: 4.0396
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6692 - loss: 4.1913 - val_accuracy: 0.5417 - val_loss: 4.0027
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6916 - loss: 4.2413 - val_accuracy: 0.6250 - val_loss: 3.9722
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7118 - loss: 3.9758 - val_accuracy: 0.7083 - val_loss: 3.9378
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6938 - loss: 4.0957 - val_accuracy: 0.7083 - val_loss: 3.9042
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8271 - loss: 3.7773 - val_accuracy: 0.6250 - val_loss: 3.8680
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8575 - loss: 3.6575 - val_accuracy: 0.6250 - val_loss: 3.8314
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8894 - loss: 3.6002 - val_accuracy: 0.6667 - val_loss: 3.7979
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9338 - loss: 3.4103 - val_accuracy: 0.6667 - val_loss: 3.7601
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9136 - loss: 3.3399 - val_accuracy: 0.5833 - val_loss: 3.7196
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9548 - loss: 3.2401 - val_accuracy: 0.5833 - val_loss: 3.6779
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9828 - loss: 3.1621 - val_accuracy: 0.5833 - val_loss: 3.6366
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9813 - loss: 3.0854 - val_accuracy: 0.5833 - val_loss: 3.5925
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9828 - loss: 2.9708 - val_accuracy: 0.5833 - val_loss: 3.5447
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9813 - loss: 2.9429 - val_accuracy: 0.6250 - val_loss: 3.4967
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.8287 - val_accuracy: 0.6250 - val_loss: 3.4470
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9735 - loss: 2.7778 - val_accuracy: 0.5833 - val_loss: 3.3917
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9828 - loss: 2.7149 - val_accuracy: 0.5833 - val_loss: 3.3375
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9564 - loss: 2.7194 - val_accuracy: 0.5833 - val_loss: 3.2682
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9828 - loss: 2.6511 - val_accuracy: 0.6250 - val_loss: 3.1948
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9946 - loss: 2.5064 - val_accuracy: 0.6250 - val_loss: 3.1345
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9774 - loss: 2.4614 - val_accuracy: 0.5833 - val_loss: 3.0969
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 2.3919 - val_accuracy: 0.5833 - val_loss: 3.0509
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9774 - loss: 2.3576 - val_accuracy: 0.5833 - val_loss: 2.9946
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 2.2535 - val_accuracy: 0.5833 - val_loss: 2.9037
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9907 - loss: 2.2239 - val_accuracy: 0.5833 - val_loss: 2.8238
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9509 - loss: 2.1973 - val_accuracy: 0.5833 - val_loss: 2.7518
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.1028 - val_accuracy: 0.6250 - val_loss: 2.6788
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9657 - loss: 2.0858 - val_accuracy: 0.6250 - val_loss: 2.6123
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9774 - loss: 2.0114 - val_accuracy: 0.5833 - val_loss: 2.5553
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.9309 - val_accuracy: 0.5833 - val_loss: 2.5084
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.8918 - val_accuracy: 0.5833 - val_loss: 2.4706
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9852 - loss: 1.8534 - val_accuracy: 0.5833 - val_loss: 2.4289
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9828 - loss: 1.8253 - val_accuracy: 0.5833 - val_loss: 2.3737
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.7369 - val_accuracy: 0.5833 - val_loss: 2.3325
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.6924 - val_accuracy: 0.5833 - val_loss: 2.2957
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.6489 - val_accuracy: 0.5833 - val_loss: 2.2553
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.6068 - val_accuracy: 0.5833 - val_loss: 2.2242
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.5531 - val_accuracy: 0.5833 - val_loss: 2.1865
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9946 - loss: 1.5351 - val_accuracy: 0.5833 - val_loss: 2.1501
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.4784 - val_accuracy: 0.5833 - val_loss: 2.1209
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4345 - val_accuracy: 0.5833 - val_loss: 2.0920
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.3936 - val_accuracy: 0.5833 - val_loss: 2.0568
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.3574 - val_accuracy: 0.5833 - val_loss: 2.0207
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9946 - loss: 1.3250 - val_accuracy: 0.5833 - val_loss: 1.9728
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.2931 - val_accuracy: 0.5833 - val_loss: 1.9129
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.2503 - val_accuracy: 0.5833 - val_loss: 1.8545
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.2158 - val_accuracy: 0.5833 - val_loss: 1.7900
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9828 - loss: 1.1858 - val_accuracy: 0.6667 - val_loss: 1.7355
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.1506 - val_accuracy: 0.6667 - val_loss: 1.6938
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.1282 - val_accuracy: 0.6667 - val_loss: 1.6738
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.0823 - val_accuracy: 0.6667 - val_loss: 1.6531
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.0658 - val_accuracy: 0.6667 - val_loss: 1.6157
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.0302 - val_accuracy: 0.6667 - val_loss: 1.5881
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9907 - loss: 1.0101 - val_accuracy: 0.6250 - val_loss: 1.5486
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.9754 - val_accuracy: 0.6250 - val_loss: 1.4982
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.9611 - val_accuracy: 0.6250 - val_loss: 1.4652
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.9295 - val_accuracy: 0.6250 - val_loss: 1.4484
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.9048 - val_accuracy: 0.6667 - val_loss: 1.4216
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.8735 - val_accuracy: 0.6667 - val_loss: 1.3901
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.8500 - val_accuracy: 0.6667 - val_loss: 1.3628
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.8346 - val_accuracy: 0.6667 - val_loss: 1.3378
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.8167 - val_accuracy: 0.6667 - val_loss: 1.3046
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.7857 - val_accuracy: 0.7500 - val_loss: 1.2712
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.7693 - val_accuracy: 0.7500 - val_loss: 1.2436
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.7566 - val_accuracy: 0.7500 - val_loss: 1.2226
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.7265 - val_accuracy: 0.7917 - val_loss: 1.1993
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.7047 - val_accuracy: 0.8333 - val_loss: 1.1770
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.6845 - val_accuracy: 0.8750 - val_loss: 1.1554
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.6664 - val_accuracy: 0.8750 - val_loss: 1.1327
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.6517 - val_accuracy: 0.8750 - val_loss: 1.1098
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9946 - loss: 0.6395 - val_accuracy: 0.9167 - val_loss: 1.0876
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.6226 - val_accuracy: 0.8750 - val_loss: 1.0685
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.6051 - val_accuracy: 0.8750 - val_loss: 1.0510
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.5863 - val_accuracy: 0.8750 - val_loss: 1.0383
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.5727 - val_accuracy: 0.7500 - val_loss: 1.0269
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.5600 - val_accuracy: 0.7500 - val_loss: 1.0099
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.5453 - val_accuracy: 0.7917 - val_loss: 0.9918
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.5272 - val_accuracy: 0.7917 - val_loss: 0.9753
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.5307 - val_accuracy: 0.8750 - val_loss: 0.9474
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.5082 - val_accuracy: 0.9583 - val_loss: 0.9158
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.4935 - val_accuracy: 0.9167 - val_loss: 0.8961
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.4842 - val_accuracy: 0.9167 - val_loss: 0.8826
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.4674 - val_accuracy: 0.9167 - val_loss: 0.8717
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9946 - loss: 0.4708 - val_accuracy: 0.9167 - val_loss: 0.8604
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.4460 - val_accuracy: 0.9583 - val_loss: 0.8577
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.4343 - val_accuracy: 0.9583 - val_loss: 0.8507
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.4310 - val_accuracy: 0.9583 - val_loss: 0.8413
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9946 - loss: 0.4205 - val_accuracy: 0.9583 - val_loss: 0.8336
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.4076 - val_accuracy: 0.9583 - val_loss: 0.8239
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.4021 - val_accuracy: 0.9583 - val_loss: 0.8135
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9828 - loss: 0.4085 - val_accuracy: 0.9583 - val_loss: 0.7937
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.4030 - val_accuracy: 0.9583 - val_loss: 0.7850
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9907 - loss: 0.4044 - val_accuracy: 0.9167 - val_loss: 0.7834
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.3729 - val_accuracy: 0.9167 - val_loss: 0.7705
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9828 - loss: 0.3993 - val_accuracy: 0.9167 - val_loss: 0.7646
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.3630 - val_accuracy: 0.8750 - val_loss: 0.7522
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.3550 - val_accuracy: 0.9167 - val_loss: 0.7286
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.3642 - val_accuracy: 0.8750 - val_loss: 0.7210
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.3538 - val_accuracy: 0.8750 - val_loss: 0.7205
# Validation Accuracy: 87.50%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step

# %%
print("Classification Report:\n")
print(classification_report(y_true_classes, y_pred_classes))

accuracy = accuracy_score(y_true_classes, y_pred_classes)
if y_test.shape[1] == 2:
    roc_auc = roc_auc_score(y_true_classes, y_pred[:, 1])
else:
    roc_auc = roc_auc_score(y_test, y_pred, multi_class='ovr', average='weighted')

precision = precision_score(y_true_classes, y_pred_classes, average='macro')
recall = recall_score(y_true_classes, y_pred_classes, average='macro')
f1 = f1_score(y_true_classes, y_pred_classes, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87        11
#            1       0.92      0.85      0.88        13
#
#     accuracy                           0.88        24
#    macro avg       0.88      0.88      0.87        24
# weighted avg       0.88      0.88      0.88        24
#
# Accuracy: 0.88
# ROC-AUC Score: 0.94
# Precision: 0.88
# Recall: 0.88
# F1-Score: 0.87

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(10, 8))
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc, average_precision_score

plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, 
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves Graph')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred[:, i])
    avg_precision = average_precision_score(y_test[:, i], y_pred[:, i])
    plt.plot(recall, precision, lw=2,
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AP = {avg_precision:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\kahch\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in c:\users\kahch\anaconda3\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (2.1.0)
# Requirement already satisfied: numpy in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (13.7.1)
# Requirement already satisfied: namex in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\kahch\anaconda3\lib\site-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kahch\anaconda3\lib\site-packages (from requests->keras-tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kahch\anaconda3\lib\site-packages (from optree->keras->keras-tuner) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kahch\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kahch\anaconda3\lib\site-packages (from rich->keras->keras-tuner) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kahch\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\kahch\anaconda3\Lib\site-packages)

# %%
import keras_tuner as kt

def build_cnn_model(hp):
    input_size = x_train_cnn.shape[1]
    output_size = y_train.shape[1]

    model = models.Sequential()

    model.add(layers.Conv1D(
        filters=hp.Choice('filters_1', values=[32, 64, 128]),
        kernel_size=hp.Choice('kernel_size_1', values=[3, 5]),
        activation='relu',
        input_shape=(input_size, 1)
    ))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling1D(pool_size=2))
    model.add(layers.Dropout(hp.Choice('dropout_1', values=[0.2, 0.3, 0.4])))

    model.add(layers.Conv1D(
        filters=hp.Choice('filters_2', values=[32, 64]),
        kernel_size=hp.Choice('kernel_size_2', values=[3, 5]),
        activation='relu'
    ))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling1D(pool_size=2))
    model.add(layers.Dropout(hp.Choice('dropout_2', values=[0.2, 0.3, 0.4])))

    model.add(layers.Flatten())

    model.add(layers.Dense(
        units=hp.Choice('units_1', values=[64, 128]),
        activation='relu',
        kernel_regularizer=regularizers.l2(0.01)
    ))
    model.add(layers.Dropout(hp.Choice('dropout_3', values=[0.3, 0.4])))

    model.add(layers.Dense(
        units=hp.Choice('units_2', values=[32, 64]),
        activation='relu',
        kernel_regularizer=regularizers.l2(0.01)
    ))
    model.add(layers.Dropout(hp.Choice('dropout_4', values=[0.3, 0.4])))

    model.add(layers.Dense(output_size, activation='sigmoid'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Choice('learning_rate', values=[0.001, 0.005, 0.01])
        ),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

tuner = kt.Hyperband(
    build_cnn_model,
    objective='val_accuracy',
    max_epochs=50,
    factor=3,
    directory='CNN_Tuning',
    project_name='CNN_Hyperparameter_Tuning'
)

hyper_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

tuner.search(
    x_train_cnn, y_train,
    validation_data=(x_test_cnn, y_test),
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[hyper_early_stopping],
    verbose=1
)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:")
print(f"Filters in Layer 1: {best_hps.get('filters_1')}")
print(f"Kernel Size in Layer 1: {best_hps.get('kernel_size_1')}")
print(f"Dropout in Layer 1: {best_hps.get('dropout_1')}")
print(f"Filters in Layer 2: {best_hps.get('filters_2')}")
print(f"Kernel Size in Layer 2: {best_hps.get('kernel_size_2')}")
print(f"Dropout in Layer 2: {best_hps.get('dropout_2')}")
print(f"Units in Dense Layer 1: {best_hps.get('units_1')}")
print(f"Dropout in Dense Layer 1: {best_hps.get('dropout_3')}")
print(f"Units in Dense Layer 2: {best_hps.get('units_2')}")
print(f"Dropout in Dense Layer 2: {best_hps.get('dropout_4')}")
print(f"Learning Rate: {best_hps.get('learning_rate')}")

best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(
    x_train_cnn, y_train,
    validation_data=(x_test_cnn, y_test),
    epochs=150,
    batch_size=32,
    class_weight=class_weights_dict,
    callbacks=[hyper_early_stopping],
    verbose=1
)

y_pred_best = best_model.predict(x_test_cnn)
y_pred_best_classes = np.argmax(y_pred_best, axis=1)
y_true_best_classes = np.argmax(y_test, axis=1)
# Out:
# Reloading Tuner from CNN_Tuning\CNN_Hyperparameter_Tuning\tuner0.json
# Best Hyperparameters:
# Filters in Layer 1: 64
# Kernel Size in Layer 1: 5
# Dropout in Layer 1: 0.2
# Filters in Layer 2: 32
# Kernel Size in Layer 2: 3
# Dropout in Layer 2: 0.4
# Units in Dense Layer 1: 64
# Dropout in Dense Layer 1: 0.3
# Units in Dense Layer 2: 64
# Dropout in Dense Layer 2: 0.3
# Learning Rate: 0.01
# Epoch 1/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.6168 - loss: 3.3206 - val_accuracy: 0.5417 - val_loss: 3.2257
# Epoch 2/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6184 - loss: 3.7248 - val_accuracy: 0.5833 - val_loss: 3.5490
# Epoch 3/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6753 - loss: 3.7649 - val_accuracy: 0.6667 - val_loss: 3.9924
# Epoch 4/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7889 - loss: 4.0294 - val_accuracy: 0.6667 - val_loss: 4.3549
# Epoch 5/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8996 - loss: 3.9643 - val_accuracy: 0.7083 - val_loss: 4.3478
# Epoch 6/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8614 - loss: 4.1954 - val_accuracy: 0.8750 - val_loss: 4.2298
# Epoch 7/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9587 - loss: 3.8995 - val_accuracy: 0.8750 - val_loss: 4.0910
# Epoch 8/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9533 - loss: 3.7375 - val_accuracy: 0.6667 - val_loss: 3.9490
# Epoch 9/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9455 - loss: 3.3996 - val_accuracy: 0.6250 - val_loss: 3.7296
# Epoch 10/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9681 - loss: 3.1207 - val_accuracy: 0.6667 - val_loss: 3.4406
# Epoch 11/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9603 - loss: 2.8026 - val_accuracy: 0.7083 - val_loss: 3.1773
# Epoch 12/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9548 - loss: 2.5745 - val_accuracy: 0.7083 - val_loss: 2.9130
# Epoch 13/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9774 - loss: 2.2277 - val_accuracy: 0.6667 - val_loss: 2.6705
# Epoch 14/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9907 - loss: 1.9205 - val_accuracy: 0.6667 - val_loss: 2.3955
# Epoch 15/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9603 - loss: 1.7295 - val_accuracy: 0.7500 - val_loss: 2.1127
# Epoch 16/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9681 - loss: 1.5241 - val_accuracy: 0.7083 - val_loss: 1.8856
# Epoch 17/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9891 - loss: 1.3299 - val_accuracy: 0.7500 - val_loss: 1.7070
# Epoch 18/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9681 - loss: 1.2255 - val_accuracy: 0.7500 - val_loss: 1.6063
# Epoch 19/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9735 - loss: 1.0931 - val_accuracy: 0.6667 - val_loss: 1.5350
# Epoch 20/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9852 - loss: 0.9764 - val_accuracy: 0.6667 - val_loss: 1.4546
# Epoch 21/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9774 - loss: 0.9181 - val_accuracy: 0.6667 - val_loss: 1.3847
# Epoch 22/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9774 - loss: 0.8873 - val_accuracy: 0.7083 - val_loss: 1.3308
# Epoch 23/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9650 - loss: 0.7969 - val_accuracy: 0.7083 - val_loss: 1.2824
# Epoch 24/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9774 - loss: 0.7636 - val_accuracy: 0.7500 - val_loss: 1.2602
# Epoch 25/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.7120 - val_accuracy: 0.7500 - val_loss: 1.2157
# Epoch 26/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9744 - loss: 0.7490 - val_accuracy: 0.7500 - val_loss: 1.2080
# Epoch 27/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9852 - loss: 0.6922 - val_accuracy: 0.7917 - val_loss: 1.2007
# Epoch 28/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9127 - loss: 1.0660 - val_accuracy: 0.8750 - val_loss: 1.0949
# Epoch 29/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9720 - loss: 0.7312 - val_accuracy: 0.8333 - val_loss: 1.1504
# Epoch 30/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9416 - loss: 0.8532 - val_accuracy: 0.7083 - val_loss: 1.2431
# Epoch 31/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9946 - loss: 0.8415 - val_accuracy: 0.5833 - val_loss: 1.4152
# Epoch 32/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9681 - loss: 0.8979 - val_accuracy: 0.6250 - val_loss: 1.4794
# Epoch 33/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9268 - loss: 1.0396 - val_accuracy: 0.6250 - val_loss: 1.4474
# Epoch 34/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9907 - loss: 0.9530 - val_accuracy: 0.6667 - val_loss: 1.4514
# Epoch 35/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9891 - loss: 0.9680 - val_accuracy: 0.7500 - val_loss: 1.4393
# Epoch 36/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9720 - loss: 0.9726 - val_accuracy: 0.7500 - val_loss: 1.4308
# Epoch 37/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9798 - loss: 0.9293 - val_accuracy: 0.7917 - val_loss: 1.3837
# Epoch 38/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9891 - loss: 0.9487 - val_accuracy: 0.7500 - val_loss: 1.3853
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step

# %%
print("Classification Report:")
print(classification_report(y_true_best_classes, y_pred_best_classes))

accuracy = accuracy_score(y_true_best_classes, y_pred_best_classes)
roc_auc = roc_auc_score(y_test, y_pred_best, multi_class='ovr', average='weighted')
precision = precision_score(y_true_best_classes, y_pred_best_classes, average='macro')
recall = recall_score(y_true_best_classes, y_pred_best_classes, average='macro')
f1 = f1_score(y_true_best_classes, y_pred_best_classes, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"ROC-AUC Score: {roc_auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        11
#            1       0.81      1.00      0.90        13
#
#     accuracy                           0.88        24
#    macro avg       0.91      0.86      0.87        24
# weighted avg       0.90      0.88      0.87        24
#
# Accuracy: 0.88
# ROC-AUC Score: 0.93
# Precision: 0.91
# Recall: 0.86
# F1-Score: 0.87

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true_best_classes, y_pred_best_classes)

plt.figure(figsize=(10, 8))
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title('Confusion Matrix')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_best[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, 
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves Graph')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 8))

n_classes = y_test.shape[1]

for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_test[:, i], y_pred_best[:, i])
    avg_precision = average_precision_score(y_test[:, i], y_pred_best[:, i])
    plt.plot(recall, precision, lw=2,
                label=f'Class {label_encoder.inverse_transform([i])[0]} (AP = {avg_precision:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 390, 128)       │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 390, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 195, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 195, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 193, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 193, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 96, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 96, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 6144)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       786,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,461,832 (9.39 MB)
#  Trainable params: 820,482 (3.13 MB)
#  Non-trainable params: 384 (1.50 KB)
#  Optimizer params: 1,640,966 (6.26 MB)

# %%
best_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_8 (Conv1D)               │ (None, 388, 64)        │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 388, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 194, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 194, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 192, 32)        │         6,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 192, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 96, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 96, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │       196,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 623,336 (2.38 MB)
#  Trainable params: 207,714 (811.38 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 415,430 (1.58 MB)

# %%
import shap

subset_data = x_test_cnn

explainer = shap.DeepExplainer(model, subset_data)

shap_values = explainer.shap_values(subset_data)
# Out:
# c:\Users\kahch\anaconda3\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_135
# Received: inputs=['Tensor(shape=(24, 392, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_135
# Received: inputs=['Tensor(shape=(48, 392, 1))']
#   warnings.warn(msg)

# %%
feature_names = data.drop(columns=['subject_id', 'label_sleep']).columns.tolist()
expected_value = explainer.expected_value[0].numpy()

shap.plots.waterfall(
    shap.Explanation(
        values=shap_values[0, :, 0, 0],
        base_values=expected_value,
        data=subset_data[0].flatten(),
        feature_names=feature_names
    ),
)

# %%
shap.initjs()
subset_data_reshaped = subset_data.reshape(subset_data.shape[0], subset_data.shape[1])

shap.plots.force(
    expected_value,
    shap_values[:, :, 0, 0],
    subset_data_reshaped,
    feature_names=feature_names
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iM9Y2NNTBCBXBLIWAJ9V8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49689802527427673, "link": "identity", "featureNames": ["label_first_scenario", "label_time_exp", "period", "segment_id", "EDA_filtered_mean_Bl", "EDA_filtered_min_Bl", "EDA_filtered_max_Bl", "EDA_filtered_std_Bl", "EDA_tonic_mean_Bl", "EDA_tonic_min_Bl", "EDA_tonic_max_Bl", "EDA_tonic_std_Bl", "SCR_Peaks_freq_Bl", "ECG_Rate_Mean_Bl", "HRV_MeanNN_Bl", "HRV_SDNN_Bl", "HRV_SDANN1_Bl", "HRV_SDNNI1_Bl", "HRV_SDANN2_Bl", "HRV_SDNNI2_Bl", "HRV_RMSSD_Bl", "HRV_SDSD_Bl", "HRV_CVNN_Bl", "HRV_CVSD_Bl", "HRV_MedianNN_Bl", "HRV_MadNN_Bl", "HRV_MCVNN_Bl", "HRV_IQRNN_Bl", "HRV_pNN50_Bl", "HRV_pNN20_Bl", "HRV_HTI_Bl", "HRV_TINN_Bl", "HRV_LF_Bl", "HRV_HF_Bl", "HRV_VHF_Bl", "HRV_LFHF_Bl", "HRV_LFn_Bl", "HRV_HFn_Bl", "HRV_LnHF_Bl", "HRV_SD1_Bl", "HRV_SD2_Bl", "HRV_SD1SD2_Bl", "HRV_S_Bl", "HRV_CSI_Bl", "HRV_CVI_Bl", "HRV_CSI_Modified_Bl", "HRV_PIP_Bl", "HRV_IALS_Bl", "HRV_PSS_Bl", "HRV_PAS_Bl", "HRV_GI_Bl", "HRV_SI_Bl", "HRV_AI_Bl", "HRV_PI_Bl", "HRV_C1d_Bl", "HRV_C1a_Bl", "HRV_SD1d_Bl", "HRV_SD1a_Bl", "HRV_C2d_Bl", "HRV_C2a_Bl", "HRV_SD2d_Bl", "HRV_SD2a_Bl", "HRV_Cd_Bl", "HRV_Ca_Bl", "HRV_SDNNd_Bl", "HRV_SDNNa_Bl", "HRV_DFA_alpha1_Bl", "HRV_DFA_alpha1_ExpRange_Bl", "HRV_DFA_alpha1_ExpMean_Bl", "HRV_DFA_alpha1_DimRange_Bl", "HRV_DFA_alpha1_DimMean_Bl", "HRV_DFA_alpha2_Bl", "HRV_DFA_alpha2_ExpRange_Bl", "HRV_DFA_alpha2_ExpMean_Bl", "HRV_DFA_alpha2_DimRange_Bl", "HRV_DFA_alpha2_DimMean_Bl", "HRV_ApEn_Bl", "HRV_SampEn_Bl", "HRV_ShanEn_Bl", "HRV_FuzzyEn_Bl", "HRV_MSE_Bl", "HRV_CMSE_Bl", "HRV_RCMSE_Bl", "HRV_CD_Bl", "HRV_HFD_Bl", "HRV_KFD_Bl", "HRV_LZC_Bl", "RSP_Rate_Mean_Bl", "RSP_Amplitude_Mean_Bl", "RSP_Phase_Duration_Inspiration_Bl", "RSP_Phase_Duration_Expiration_Bl", "RSP_Phase_Duration_Ratio_Bl", "RRV_RMSSD_Bl", "RRV_MeanBB_Bl", "RRV_SDBB_Bl", "RRV_SDSD_Bl", "RRV_CVBB_Bl", "RRV_CVSD_Bl", "RRV_MedianBB_Bl", "RRV_MadBB_Bl", "RRV_MCVBB_Bl", "RRV_LF_Bl", "RRV_HF_Bl", "RRV_LFHF_Bl", "RRV_SD1_Bl", "RRV_SD2_Bl", "RRV_SD2SD1_Bl", "RRV_ApEn_Bl", "RRV_SampEn_Bl", "RRV_DFA_alpha2_Bl", "RRV_DFA_alpha2_ExpRange_Bl", "RRV_DFA_alpha2_ExpMean_Bl", "RRV_DFA_alpha2_DimRange_Bl", "RRV_DFA_alpha2_DimMean_Bl", "SCR_Peaks_N_Bl", "SCR_Peaks_Amplitude_Mean_Bl", "RSA_P2T_Mean_Bl", "RSA_P2T_Mean_log_Bl", "RSA_P2T_SD_Bl", "RSA_P2T_NoRSA_Bl", "RSA_PorgesBohrer_Bl", "RSA_Gates_Mean_Bl", "RSA_Gates_Mean_log_Bl", "RSA_Gates_SD_Bl", "EDA_filtered_mean_Dr", "EDA_filtered_min_Dr", "EDA_filtered_max_Dr", "EDA_filtered_std_Dr", "EDA_tonic_mean_Dr", "EDA_tonic_min_Dr", "EDA_tonic_max_Dr", "EDA_tonic_std_Dr", "SCR_Peaks_freq_Dr", "ECG_Rate_Mean_Dr", "HRV_MeanNN_Dr", "HRV_SDNN_Dr", "HRV_SDANN1_Dr", "HRV_SDNNI1_Dr", "HRV_SDANN2_Dr", "HRV_SDNNI2_Dr", "HRV_SDANN5_Dr", "HRV_SDNNI5_Dr", "HRV_RMSSD_Dr", "HRV_SDSD_Dr", "HRV_CVNN_Dr", "HRV_CVSD_Dr", "HRV_MedianNN_Dr", "HRV_MadNN_Dr", "HRV_MCVNN_Dr", "HRV_IQRNN_Dr", "HRV_pNN50_Dr", "HRV_pNN20_Dr", "HRV_HTI_Dr", "HRV_TINN_Dr", "HRV_VLF_Dr", "HRV_LF_Dr", "HRV_HF_Dr", "HRV_VHF_Dr", "HRV_LFHF_Dr", "HRV_LFn_Dr", "HRV_HFn_Dr", "HRV_LnHF_Dr", "HRV_SD1_Dr", "HRV_SD2_Dr", "HRV_SD1SD2_Dr", "HRV_S_Dr", "HRV_CSI_Dr", "HRV_CVI_Dr", "HRV_CSI_Modified_Dr", "HRV_PIP_Dr", "HRV_IALS_Dr", "HRV_PSS_Dr", "HRV_PAS_Dr", "HRV_GI_Dr", "HRV_SI_Dr", "HRV_AI_Dr", "HRV_PI_Dr", "HRV_C1d_Dr", "HRV_C1a_Dr", "HRV_SD1d_Dr", "HRV_SD1a_Dr", "HRV_C2d_Dr", "HRV_C2a_Dr", "HRV_SD2d_Dr", "HRV_SD2a_Dr", "HRV_Cd_Dr", "HRV_Ca_Dr", "HRV_SDNNd_Dr", "HRV_SDNNa_Dr", "HRV_DFA_alpha1_Dr", "HRV_DFA_alpha1_ExpRange_Dr", "HRV_DFA_alpha1_ExpMean_Dr", "HRV_DFA_alpha1_DimRange_Dr", "HRV_DFA_alpha1_DimMean_Dr", "HRV_DFA_alpha2_Dr", "HRV_DFA_alpha2_ExpRange_Dr", "HRV_DFA_alpha2_ExpMean_Dr", "HRV_DFA_alpha2_DimRange_Dr", "HRV_DFA_alpha2_DimMean_Dr", "HRV_ApEn_Dr", "HRV_SampEn_Dr", "HRV_ShanEn_Dr", "HRV_FuzzyEn_Dr", "HRV_MSE_Dr", "HRV_CMSE_Dr", "HRV_RCMSE_Dr", "HRV_CD_Dr", "HRV_HFD_Dr", "HRV_KFD_Dr", "HRV_LZC_Dr", "RSP_Rate_Mean_Dr", "RSP_Amplitude_Mean_Dr", "RSP_Phase_Duration_Inspiration_Dr", "RSP ...

# %%
shap.summary_plot(
    shap_values[:, :, 0, 0],
    subset_data_reshaped,
    feature_names=feature_names
)

# %%
shap_exp = shap.Explanation(
    values=shap_values[:, :, 0, 0],
    base_values=expected_value,
    data=subset_data_reshaped,
    feature_names=feature_names
)

shap.plots.beeswarm(shap_exp)

# %%
shap.plots.bar(
    shap.Explanation(
        values=shap_values[0, :, 0, 0],
        base_values=expected_value,
        data=subset_data[0].flatten(),
        feature_names=feature_names
    )
)

# %%
pip install quantus
# Out:
# Requirement already satisfied: quantus in c:\users\kahch\anaconda3\lib\site-packages (0.5.3)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.26.4)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (2.2.2)
# Requirement already satisfied: opencv-python>=4.5.5.62 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (4.11.0.86)
# Requirement already satisfied: scikit-image>=0.19.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (0.24.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.5.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (1.13.1)
# Requirement already satisfied: tqdm>=4.62.3 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (4.66.5)
# Requirement already satisfied: matplotlib>=3.3.4 in c:\users\kahch\anaconda3\lib\site-packages (from quantus) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kahch\anaconda3\lib\site-packages (from matplotlib>=3.3.4->quantus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kahch\anaconda3\lib\site-packages (from pandas>=1.5.3->quantus) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kahch\anaconda3\lib\site-packages (from pandas>=1.5.3->quantus) (2023.3)
# Requirement already satisfied: networkx>=2.8 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (3.3)
# Requirement already satisfied: imageio>=2.33 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-image>=0.19.3->quantus) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->quantus) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kahch\anaconda3\lib\site-packages (from scikit-learn>=0.24.2->quantus) (3.5.0)
# Requirement already satisfied: colorama in c:\users\kahch\anaconda3\lib\site-packages (from tqdm>=4.62.3->quantus) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kahch\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->quantus) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kahch\anaconda3\Lib\site-packages)

# %%
import quantus

def shap_explain_func(model, inputs, targets, **kwargs):

    if inputs.ndim == 3 and inputs.shape[1] == 1:
        inputs_reshaped = np.transpose(inputs, (0, 2, 1))
    else:
        inputs_reshaped = inputs

    background = inputs_reshaped[:100]

    explainer = shap.DeepExplainer(model, background)

    shap_values = explainer.shap_values(inputs_reshaped)

    explanations = shap_values[:, :, 0, 0]
    
    return explanations

def evaluate_xai_metrics(x_batch: np.ndarray, y_batch: np.ndarray, 
                        attributions: np.ndarray, n_samples):
    
    x_batch = x_batch[:n_samples]
    y_batch = y_batch[:n_samples]
    attributions = attributions[:n_samples]

    metrics = {
        "robustness": quantus.AvgSensitivity(
            nr_samples=2,
            lower_bound=0.2,
            norm_numerator=quantus.norm_func.fro_norm,
            norm_denominator=quantus.norm_func.fro_norm,
            perturb_func=quantus.perturb_func.uniform_noise,
            similarity_func=quantus.similarity_func.difference,
            abs=True,
            normalise=False,
            aggregate_func=np.mean,
            return_aggregate=True,
            disable_warnings=True,
            display_progressbar=True,
        ),
        "complexity": quantus.Sparseness(
            abs=True,
            normalise=True,
            disable_warnings=True,
            display_progressbar=True,
            return_aggregate=True,
        ),
        "randomisation": quantus.MPRT(
            similarity_func=quantus.similarity_func.correlation_spearman,
            return_average_correlation=True,
            aggregate_func=np.mean,
            layer_order="independent",
            disable_warnings=True,
            normalise=True,
            abs=True,
            display_progressbar=True,
        )
    }

    results = {}
    for metric_name, metric in metrics.items():
        score = metric(
            model=model,
            x_batch=x_batch,
            y_batch=y_batch,
            a_batch=attributions,
            explain_func=shap_explain_func
        )
        score_value = np.mean(score) if isinstance(score, (np.ndarray, list)) else score
            
        results[metric_name] = score_value
        print(f"{metric_name.capitalize()} Score: {score_value:.4f}")
    
    return results

def plot_metric_results(results):
    results = {k: v for k, v in results.items() if v is not None}
        
    plt.figure(figsize=(10, 6))
    metrics = list(results.keys())
    scores = list(results.values())
    
    bars = plt.bar(metrics, scores)
    plt.title('XAI Evaluation Metrics')
    plt.xticks(rotation=45)
    plt.ylabel('Score')
    
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.4f}',
                ha='center', va='bottom')
    
    plt.tight_layout()
    plt.show()


y_test_classes = np.argmax(y_test, axis=1)

results = evaluate_xai_metrics(
    x_batch=x_test_cnn,
    y_batch=y_test_classes,
    attributions=shap_values[:, :, 0, 0],
    n_samples=100
)

plot_metric_results(results)
# Out:
#   0%|          | 0/1.0 [00:00<?, ?it/s]
# c:\Users\kahch\anaconda3\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_135
# Received: inputs=['Tensor(shape=(24, 392, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_135
# Received: inputs=['Tensor(shape=(48, 392, 1))']
#   warnings.warn(msg)
# Robustness Score: 0.1745
#   0%|          | 0/1.0 [00:00<?, ?it/s]
# Complexity Score: 0.5497
#   0%|          | 0/168 [00:00<?, ?it/s]
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer_2
# Received: inputs=['Tensor(shape=(24, 392, 1))']
#   warnings.warn(msg)
# c:\Users\kahch\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer_2
# Received: inputs=['Tensor(shape=(48, 392, 1))']
#   warnings.warn(msg)
# Randomisation Score: 0.6615
